# %%
import numpy as np
import tensorflow as tf
from q2_initialization import xavier_weight_init
import data_utils.utils as du
import data_utils.ner as ner
from utils import data_iterator
from model import LanguageModel

# %%
class Config(object):
  """Holds model hyperparams and data information.

  The config class is used to store various hyperparameters and dataset
  information parameters. Model objects are passed a Config() object at
  instantiation.
  """
  embed_size = 50
  batch_size = 64
  label_size = 5
  hidden_size = 100
  max_epochs = 1
  early_stopping = 2
  dropout = 0.9
  lr = 0.001
  l2 = 0.001  # regularization term
  window_size = 3
config = Config()

# %%
wv, word_to_num, num_to_word = ner.load_wv('data/ner/vocab.txt', 'data/ner/wordVectors.txt')

# %%
wv.shape
# Out:
# (100232, 50)

# %%
tagnames = ['O', 'LOC', 'MISC', 'ORG', 'PER']
num_to_tag = dict(enumerate(tagnames))
tag_to_num = {v:k for k,v in num_to_tag.iteritems()}

# %%
docs = du.load_dataset('data/ner/train')

# %%
docs ## docs is a list of sentences-lists of words/types couples.
# Out:
# [[['EU', 'ORG'],
#   ['rejects', 'O'],
#   ['German', 'MISC'],
#   ['call', 'O'],
#   ['to', 'O'],
#   ['boycott', 'O'],
#   ['British', 'MISC'],
#   ['lamb', 'O'],
#   ['.', 'O']],
#  [['Peter', 'PER'], ['Blackburn', 'PER']],
#  [['BRUSSELS', 'LOC'], ['1996-08-22', 'O']],
#  [['The', 'O'],
#   ['European', 'ORG'],
#   ['Commission', 'ORG'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['it', 'O'],
#   ['disagreed', 'O'],
#   ['with', 'O'],
#   ['German', 'MISC'],
#   ['advice', 'O'],
#   ['to', 'O'],
#   ['consumers', 'O'],
#   ['to', 'O'],
#   ['shun', 'O'],
#   ['British', 'MISC'],
#   ['lamb', 'O'],
#   ['until', 'O'],
#   ['scientists', 'O'],
#   ['determine', 'O'],
#   ['whether', 'O'],
#   ['mad', 'O'],
#   ['cow', 'O'],
#   ['disease', 'O'],
#   ['can', 'O'],
#   ['be', 'O'],
#   ['transmitted', 'O'],
#   ['to', 'O'],
#   ['sheep', 'O'],
#   ['.', 'O']],
#  [['Germany', 'LOC'],
#   ["'s", 'O'],
#   ['representative', 'O'],
#   ['to', 'O'],
#   ['the', 'O'],
#   ['European', 'ORG'],
#   ['Union', 'ORG'],
#   ["'s", 'O'],
#   ['veterinary', 'O'],
#   ['committee', 'O'],
#   ['Werner', 'PER'],
#   ['Zwingmann', 'PER'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['consumers', 'O'],
#   ['should', 'O'],
#   ['buy', 'O'],
#   ['sheepmeat', 'O'],
#   ['from', 'O'],
#   ['countries', 'O'],
#   ['other', 'O'],
#   ['than', 'O'],
#   ['Britain', 'LOC'],
#   ['until', 'O'],
#   ['the', 'O'],
#   ['scientific', 'O'],
#   ['advice', 'O'],
#   ['was', 'O'],
#   ['clearer', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['We', 'O'],
#   ['do', 'O'],
#   ["n't", 'O'],
#   ['support', 'O'],
#   ['any', 'O'],
#   ['such', 'O'],
#   ['recommendation', 'O'],
#   ['because', 'O'],
#   ['we', 'O'],
#   ['do', 'O'],
#   ["n't", 'O'],
#   ['see', 'O'],
#   ['any', 'O'],
#   ['grounds', 'O'],
#   ['for', 'O'],
#   ['it', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['the', 'O'],
#   ['Commission', 'ORG'],
#   ["'s", 'O'],
#   ['chief', 'O'],
#   ['spokesman', 'O'],
#   ['Nikolaus', 'PER'],
#   ['van', 'PER'],
#   ['der', 'PER'],
#   ['Pas', 'PER'],
#   ['told', 'O'],
#   ['a', 'O'],
#   ['news', 'O'],
#   ['briefing', 'O'],
#   ['.', 'O']],
#  [['He', 'O'],
#   ['said', 'O'],
#   ['further', 'O'],
#   ['scientific', 'O'],
#   ['study', 'O'],
#   ['was', 'O'],
#   ['required', 'O'],
#   ['and', 'O'],
#   ['if', 'O'],
#   ['it', 'O'],
#   ['was', 'O'],
#   ['found', 'O'],
#   ['that', 'O'],
#   ['action', 'O'],
#   ['was', 'O'],
#   ['needed', 'O'],
#   ['it', 'O'],
#   ['should', 'O'],
#   ['be', 'O'],
#   ['taken', 'O'],
#   ['by', 'O'],
#   ['the', 'O'],
#   ['European', 'ORG'],
#   ['Union', 'ORG'],
#   ['.', 'O']],
#  [['He', 'O'],
#   ['said', 'O'],
#   ['a', 'O'],
#   ['proposal', 'O'],
#   ['last', 'O'],
#   ['month', 'O'],
#   ['by', 'O'],
#   ['EU', 'ORG'],
#   ['Farm', 'O'],
#   ['Commissioner', 'O'],
#   ['Franz', 'PER'],
#   ['Fischler', 'PER'],
#   ['to', 'O'],
#   ['ban', 'O'],
#   ['sheep', 'O'],
#   ['brains', 'O'],
#   [',', 'O'],
#   ['spleens', 'O'],
#   ['and', 'O'],
#   ['spinal', 'O'],
#   ['cords', 'O'],
#   ['from', 'O'],
#   ['the', 'O'],
#   ['human', 'O'],
#   ['and', 'O'],
#   ['animal', 'O'],
#   ['food', 'O'],
#   ['chains', 'O'],
#   ['was', 'O'],
#   ['a', 'O'],
#   ['highly', 'O'],
#   ['specific', 'O'],
#   ['and', 'O'],
#   ['precautionary', 'O'],
#   ['move', 'O'],
#   ['to', 'O'],
#   ['protect', 'O'],
#   ['human', 'O'],
#   ['health', 'O'],
#   ['.', 'O']],
#  [['Fischler', 'PER'],
#   ['proposed', 'O'],
#   ['EU-wide', 'MISC'],
#   ['measures', 'O'],
#   ['after', 'O'],
#   ['reports', 'O'],
#   ['from', 'O'],
#   ['Britain', 'LOC'],
#   ['and', 'O'],
#   ['France', 'LOC'],
#   ['that', 'O'],
#   ['under', 'O'],
#   ['laboratory', 'O'],
#   ['conditions', 'O'],
#   ['sheep', 'O'],
#   ['could', 'O'],
#   ['contract', 'O'],
#   ['Bovine', 'MISC'],
#   ['Spongiform', 'MISC'],
#   ['Encephalopathy', 'MISC'],
#   ['(', 'O'],
#   ['BSE', 'MISC'],
#   [')', 'O'],
#   ['--', 'O'],
#   ['mad', 'O'],
#   ['cow', 'O'],
#   ['disease', 'O'],
#   ['.', 'O']],
#  [['But', 'O'],
#   ['Fischler', 'PER'],
#   ['agreed', 'O'],
#   ['to', 'O'],
#   ['review', 'O'],
#   ['his', 'O'],
#   ['proposal', 'O'],
#   ['after', 'O'],
#   ['the', 'O'],
#   ['EU', 'ORG'],
#   ["'s", 'O'],
#   ['standing', 'O'],
#   ['veterinary', 'O'],
#   ['committee', 'O'],
#   [',', 'O'],
#   ['mational', 'O'],
#   ['animal', 'O'],
#   ['health', 'O'],
#   ['officials', 'O'],
#   [',', 'O'],
#   ['questioned', 'O'],
#   ['if', 'O'],
#   ['such', 'O'],
#   ['action', 'O'],
#   ['was', 'O'],
#   ['justified', 'O'],
#   ['as', 'O'],
#   ['there', 'O'],
#   ['was', 'O'],
#   ['only', 'O'],
#   ['a', 'O'],
#   ['slight', 'O'],
#   ['risk', 'O'],
#   ['to', 'O'],
#   ['human', 'O'],
#   ['health', 'O'],
#   ['.', 'O']],
#  [['Spanish', 'MISC'],
#   ['Farm', 'O'],
#   ['Minister', 'O'],
#   ['Loyola', 'PER'],
#   ['de', 'PER'],
#   ['Palacio', 'PER'],
#   ['had', 'O'],
#   ['earlier', 'O'],
#   ['accused', 'O'],
#   ['Fischler', 'PER'],
#   ['at', 'O'],
#   ['an', 'O'],
#   ['EU', 'ORG'],
#   ['farm', 'O'],
#   ['ministers', 'O'],
#   ["'", 'O'],
#   ['meeting', 'O'],
#   ['of', 'O'],
#   ['causing', 'O'],
#   ['unjustified', 'O'],
#   ['alarm', 'O'],
#   ['through', 'O'],
#   ['"', 'O'],
#   ['dangerous', 'O'],
#   ['generalisation', 'O'],
#   ['.', 'O'],
#   ['"', 'O']],
#  [['.', 'O']],
#  [['Only', 'O'],
#   ['France', 'LOC'],
#   ['and', 'O'],
#   ['Britain', 'LOC'],
#   ['backed', 'O'],
#   ['Fischler', 'PER'],
#   ["'s", 'O'],
#   ['proposal', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['EU', 'ORG'],
#   ["'s", 'O'],
#   ['scientific', 'O'],
#   ['veterinary', 'O'],
#   ['and', 'O'],
#   ['multidisciplinary', 'O'],
#   ['committees', 'O'],
#   ['are', 'O'],
#   ['due', 'O'],
#   ['to', 'O'],
#   ['re-examine', 'O'],
#   ['the', 'O'],
#   ['issue', 'O'],
#   ['early', 'O'],
#   ['next', 'O'],
#   ['month', 'O'],
#   ['and', 'O'],
#   ['make', 'O'],
#   ['recommendations', 'O'],
#   ['to', 'O'],
#   ['the', 'O'],
#   ['senior', 'O'],
#   ['veterinary', 'O'],
#   ['officials', 'O'],
#   ['.', 'O']],
#  [['Sheep', 'O'],
#   ['have', 'O'],
#   ['long', 'O'],
#   ['been', 'O'],
#   ['known', 'O'],
#   ['to', 'O'],
#   ['contract', 'O'],
#   ['scrapie', 'O'],
#   [',', 'O'],
#   ['a', 'O'],
#   ['brain-wasting', 'O'],
#   ['disease', 'O'],
#   ['similar', 'O'],
#   ['to', 'O'],
#   ['BSE', 'MISC'],
#   ['which', 'O'],
#   ['is', 'O'],
#   ['believed', 'O'],
#   ['to', 'O'],
#   ['have', 'O'],
#   ['been', 'O'],
#   ['transferred', 'O'],
#   ['to', 'O'],
#   ['cattle', 'O'],
#   ['through', 'O'],
#   ['feed', 'O'],
#   ['containing', 'O'],
#   ['animal', 'O'],
#   ['waste', 'O'],
#   ['.', 'O']],
#  [['British', 'MISC'],
#   ['farmers', 'O'],
#   ['denied', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['there', 'O'],
#   ['was', 'O'],
#   ['any', 'O'],
#   ['danger', 'O'],
#   ['to', 'O'],
#   ['human', 'O'],
#   ['health', 'O'],
#   ['from', 'O'],
#   ['their', 'O'],
#   ['sheep', 'O'],
#   [',', 'O'],
#   ['but', 'O'],
#   ['expressed', 'O'],
#   ['concern', 'O'],
#   ['that', 'O'],
#   ['German', 'MISC'],
#   ['government', 'O'],
#   ['advice', 'O'],
#   ['to', 'O'],
#   ['consumers', 'O'],
#   ['to', 'O'],
#   ['avoid', 'O'],
#   ['British', 'MISC'],
#   ['lamb', 'O'],
#   ['might', 'O'],
#   ['influence', 'O'],
#   ['consumers', 'O'],
#   ['across', 'O'],
#   ['Europe', 'LOC'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['What', 'O'],
#   ['we', 'O'],
#   ['have', 'O'],
#   ['to', 'O'],
#   ['be', 'O'],
#   ['extremely', 'O'],
#   ['careful', 'O'],
#   ['of', 'O'],
#   ['is', 'O'],
#   ['how', 'O'],
#   ['other', 'O'],
#   ['countries', 'O'],
#   ['are', 'O'],
#   ['going', 'O'],
#   ['to', 'O'],
#   ['take', 'O'],
#   ['Germany', 'LOC'],
#   ["'s", 'O'],
#   ['lead', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['Welsh', 'ORG'],
#   ['National', 'ORG'],
#   ['Farmers', 'ORG'],
#   ["'", 'ORG'],
#   ['Union', 'ORG'],
#   ['(', 'O'],
#   ['NFU', 'ORG'],
#   [')', 'O'],
#   ['chairman', 'O'],
#   ['John', 'PER'],
#   ['Lloyd', 'PER'],
#   ['Jones', 'PER'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['BBC', 'ORG'],
#   ['radio', 'ORG'],
#   ['.', 'O']],
#  [['Bonn', 'LOC'],
#   ['has', 'O'],
#   ['led', 'O'],
#   ['efforts', 'O'],
#   ['to', 'O'],
#   ['protect', 'O'],
#   ['public', 'O'],
#   ['health', 'O'],
#   ['after', 'O'],
#   ['consumer', 'O'],
#   ['confidence', 'O'],
#   ['collapsed', 'O'],
#   ['in', 'O'],
#   ['March', 'O'],
#   ['after', 'O'],
#   ['a', 'O'],
#   ['British', 'MISC'],
#   ['report', 'O'],
#   ['suggested', 'O'],
#   ['humans', 'O'],
#   ['could', 'O'],
#   ['contract', 'O'],
#   ['an', 'O'],
#   ['illness', 'O'],
#   ['similar', 'O'],
#   ['to', 'O'],
#   ['mad', 'O'],
#   ['cow', 'O'],
#   ['disease', 'O'],
#   ['by', 'O'],
#   ['eating', 'O'],
#   ['contaminated', 'O'],
#   ['beef', 'O'],
#   ['.', 'O']],
#  [['Germany', 'LOC'],
#   ['imported', 'O'],
#   ['47,600', 'O'],
#   ['sheep', 'O'],
#   ['from', 'O'],
#   ['Britain', 'LOC'],
#   ['last', 'O'],
#   ['year', 'O'],
#   [',', 'O'],
#   ['nearly', 'O'],
#   ['half', 'O'],
#   ['of', 'O'],
#   ['total', 'O'],
#   ['imports', 'O'],
#   ['.', 'O']],
#  [['It', 'O'],
#   ['brought', 'O'],
#   ['in', 'O'],
#   ['4,275', 'O'],
#   ['tonnes', 'O'],
#   ['of', 'O'],
#   ['British', 'MISC'],
#   ['mutton', 'O'],
#   [',', 'O'],
#   ['some', 'O'],
#   ['10', 'O'],
#   ['percent', 'O'],
#   ['of', 'O'],
#   ['overall', 'O'],
#   ['imports', 'O'],
#   ['.', 'O']],
#  [['Rare', 'O'],
#   ['Hendrix', 'PER'],
#   ['song', 'O'],
#   ['draft', 'O'],
#   ['sells', 'O'],
#   ['for', 'O'],
#   ['almost', 'O'],
#   ['$', 'O'],
#   ['17,000', 'O'],
#   ['.', 'O']],
#  [['LONDON', 'LOC'], ['1996-08-22', 'O']],
#  [['A', 'O'],
#   ['rare', 'O'],
#   ['early', 'O'],
#   ['handwritten', 'O'],
#   ['draft', 'O'],
#   ['of', 'O'],
#   ['a', 'O'],
#   ['song', 'O'],
#   ['by', 'O'],
#   ['U.S.', 'LOC'],
#   ['guitar', 'O'],
#   ['legend', 'O'],
#   ['Jimi', 'PER'],
#   ['Hendrix', 'PER'],
#   ['was', 'O'],
#   ['sold', 'O'],
#   ['for', 'O'],
#   ['almost', 'O'],
#   ['$', 'O'],
#   ['17,000', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['at', 'O'],
#   ['an', 'O'],
#   ['auction', 'O'],
#   ['of', 'O'],
#   ['some', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['late', 'O'],
#   ['musician', 'O'],
#   ["'s", 'O'],
#   ['favourite', 'O'],
#   ['possessions', 'O'],
#   ['.', 'O']],
#  [['A', 'O'],
#   ['Florida', 'LOC'],
#   ['restaurant', 'O'],
#   ['paid', 'O'],
#   ['10,925', 'O'],
#   ['pounds', 'O'],
#   ['(', 'O'],
#   ['$', 'O'],
#   ['16,935', 'O'],
#   [')', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['draft', 'O'],
#   ['of', 'O'],
#   ['"', 'O'],
#   ['Ai', 'MISC'],
#   ["n't", 'MISC'],
#   ['no', 'MISC'],
#   ['telling', 'MISC'],
#   ['"', 'O'],
#   [',', 'O'],
#   ['which', 'O'],
#   ['Hendrix', 'PER'],
#   ['penned', 'O'],
#   ['on', 'O'],
#   ['a', 'O'],
#   ['piece', 'O'],
#   ['of', 'O'],
#   ['London', 'LOC'],
#   ['hotel', 'O'],
#   ['stationery', 'O'],
#   ['in', 'O'],
#   ['late', 'O'],
#   ['1966', 'O'],
#   ['.', 'O']],
#  [['At', 'O'],
#   ['the', 'O'],
#   ['end', 'O'],
#   ['of', 'O'],
#   ['a', 'O'],
#   ['January', 'O'],
#   ['1967', 'O'],
#   ['concert', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['English', 'MISC'],
#   ['city', 'O'],
#   ['of', 'O'],
#   ['Nottingham', 'LOC'],
#   ['he', 'O'],
#   ['threw', 'O'],
#   ['the', 'O'],
#   ['sheet', 'O'],
#   ['of', 'O'],
#   ['paper', 'O'],
#   ['into', 'O'],
#   ['the', 'O'],
#   ['audience', 'O'],
#   [',', 'O'],
#   ['where', 'O'],
#   ['it', 'O'],
#   ['was', 'O'],
#   ['retrieved', 'O'],
#   ['by', 'O'],
#   ['a', 'O'],
#   ['fan', 'O'],
#   ['.', 'O']],
#  [['Buyers', 'O'],
#   ['also', 'O'],
#   ['snapped', 'O'],
#   ['up', 'O'],
#   ['16', 'O'],
#   ['other', 'O'],
#   ['items', 'O'],
#   ['that', 'O'],
#   ['were', 'O'],
#   ['put', 'O'],
#   ['up', 'O'],
#   ['for', 'O'],
#   ['auction', 'O'],
#   ['by', 'O'],
#   ['Hendrix', 'PER'],
#   ["'s", 'O'],
#   ['former', 'O'],
#   ['girlfriend', 'O'],
#   ['Kathy', 'PER'],
#   ['Etchingham', 'PER'],
#   [',', 'O'],
#   ['who', 'O'],
#   ['lived', 'O'],
#   ['with', 'O'],
#   ['him', 'O'],
#   ['from', 'O'],
#   ['1966', 'O'],
#   ['to', 'O'],
#   ['1969', 'O'],
#   ['.', 'O']],
#  [['They', 'O'],
#   ['included', 'O'],
#   ['a', 'O'],
#   ['black', 'O'],
#   ['lacquer', 'O'],
#   ['and', 'O'],
#   ['mother', 'O'],
#   ['of', 'O'],
#   ['pearl', 'O'],
#   ['inlaid', 'O'],
#   ['box', 'O'],
#   ['used', 'O'],
#   ['by', 'O'],
#   ['Hendrix', 'PER'],
#   ['to', 'O'],
#   ['store', 'O'],
#   ['his', 'O'],
#   ['drugs', 'O'],
#   [',', 'O'],
#   ['which', 'O'],
#   ['an', 'O'],
#   ['anonymous', 'O'],
#   ['Australian', 'MISC'],
#   ['purchaser', 'O'],
#   ['bought', 'O'],
#   ['for', 'O'],
#   ['5,060', 'O'],
#   ['pounds', 'O'],
#   ['(', 'O'],
#   ['$', 'O'],
#   ['7,845', 'O'],
#   [')', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['guitarist', 'O'],
#   ['died', 'O'],
#   ['of', 'O'],
#   ['a', 'O'],
#   ['drugs', 'O'],
#   ['overdose', 'O'],
#   ['in', 'O'],
#   ['1970', 'O'],
#   ['aged', 'O'],
#   ['27', 'O'],
#   ['.', 'O']],
#  [['China', 'LOC'],
#   ['says', 'O'],
#   ['Taiwan', 'LOC'],
#   ['spoils', 'O'],
#   ['atmosphere', 'O'],
#   ['for', 'O'],
#   ['talks', 'O'],
#   ['.', 'O']],
#  [['BEIJING', 'LOC'], ['1996-08-22', 'O']],
#  [['China', 'LOC'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['accused', 'O'],
#   ['Taipei', 'LOC'],
#   ['of', 'O'],
#   ['spoiling', 'O'],
#   ['the', 'O'],
#   ['atmosphere', 'O'],
#   ['for', 'O'],
#   ['a', 'O'],
#   ['resumption', 'O'],
#   ['of', 'O'],
#   ['talks', 'O'],
#   ['across', 'O'],
#   ['the', 'O'],
#   ['Taiwan', 'LOC'],
#   ['Strait', 'LOC'],
#   ['with', 'O'],
#   ['a', 'O'],
#   ['visit', 'O'],
#   ['to', 'O'],
#   ['Ukraine', 'LOC'],
#   ['by', 'O'],
#   ['Taiwanese', 'MISC'],
#   ['Vice', 'O'],
#   ['President', 'O'],
#   ['Lien', 'PER'],
#   ['Chan', 'PER'],
#   ['this', 'O'],
#   ['week', 'O'],
#   ['that', 'O'],
#   ['infuriated', 'O'],
#   ['Beijing', 'LOC'],
#   ['.', 'O']],
#  [['Speaking', 'O'],
#   ['only', 'O'],
#   ['hours', 'O'],
#   ['after', 'O'],
#   ['Chinese', 'MISC'],
#   ['state', 'O'],
#   ['media', 'O'],
#   ['said', 'O'],
#   ['the', 'O'],
#   ['time', 'O'],
#   ['was', 'O'],
#   ['right', 'O'],
#   ['to', 'O'],
#   ['engage', 'O'],
#   ['in', 'O'],
#   ['political', 'O'],
#   ['talks', 'O'],
#   ['with', 'O'],
#   ['Taiwan', 'LOC'],
#   [',', 'O'],
#   ['Foreign', 'ORG'],
#   ['Ministry', 'ORG'],
#   ['spokesman', 'O'],
#   ['Shen', 'PER'],
#   ['Guofang', 'PER'],
#   ['told', 'O'],
#   ['Reuters', 'ORG'],
#   [':', 'O'],
#   ['"', 'O'],
#   ['The', 'O'],
#   ['necessary', 'O'],
#   ['atmosphere', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['opening', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['talks', 'O'],
#   ['has', 'O'],
#   ['been', 'O'],
#   ['disrupted', 'O'],
#   ['by', 'O'],
#   ['the', 'O'],
#   ['Taiwan', 'LOC'],
#   ['authorities', 'O'],
#   ['.', 'O'],
#   ['"', 'O']],
#  [['State', 'O'],
#   ['media', 'O'],
#   ['quoted', 'O'],
#   ['China', 'LOC'],
#   ["'s", 'O'],
#   ['top', 'O'],
#   ['negotiator', 'O'],
#   ['with', 'O'],
#   ['Taipei', 'LOC'],
#   [',', 'O'],
#   ['Tang', 'PER'],
#   ['Shubei', 'PER'],
#   [',', 'O'],
#   ['as', 'O'],
#   ['telling', 'O'],
#   ['a', 'O'],
#   ['visiting', 'O'],
#   ['group', 'O'],
#   ['from', 'O'],
#   ['Taiwan', 'LOC'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['that', 'O'],
#   ['it', 'O'],
#   ['was', 'O'],
#   ['time', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['rivals', 'O'],
#   ['to', 'O'],
#   ['hold', 'O'],
#   ['political', 'O'],
#   ['talks', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['Now', 'O'],
#   ['is', 'O'],
#   ['the', 'O'],
#   ['time', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['two', 'O'],
#   ['sides', 'O'],
#   ['to', 'O'],
#   ['engage', 'O'],
#   ['in', 'O'],
#   ['political', 'O'],
#   ['talks', 'O'],
#   ['...', 'O']],
#  [['that', 'O'],
#   ['is', 'O'],
#   ['to', 'O'],
#   ['end', 'O'],
#   ['the', 'O'],
#   ['state', 'O'],
#   ['of', 'O'],
#   ['hostility', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['Thursday', 'O'],
#   ["'s", 'O'],
#   ['overseas', 'O'],
#   ['edition', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['People', 'ORG'],
#   ["'s", 'ORG'],
#   ['Daily', 'ORG'],
#   ['quoted', 'O'],
#   ['Tang', 'PER'],
#   ['as', 'O'],
#   ['saying', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['foreign', 'O'],
#   ['ministry', 'O'],
#   ["'s", 'O'],
#   ['Shen', 'ORG'],
#   ['told', 'O'],
#   ['Reuters', 'ORG'],
#   ['Television', 'ORG'],
#   ['in', 'O'],
#   ['an', 'O'],
#   ['interview', 'O'],
#   ['he', 'O'],
#   ['had', 'O'],
#   ['read', 'O'],
#   ['reports', 'O'],
#   ['of', 'O'],
#   ['Tang', 'PER'],
#   ["'s", 'O'],
#   ['comments', 'O'],
#   ['but', 'O'],
#   ['gave', 'O'],
#   ['no', 'O'],
#   ['details', 'O'],
#   ['of', 'O'],
#   ['why', 'O'],
#   ['the', 'O'],
#   ['negotiator', 'O'],
#   ['had', 'O'],
#   ['considered', 'O'],
#   ['the', 'O'],
#   ['time', 'O'],
#   ['right', 'O'],
#   ['for', 'O'],
#   ['talks', 'O'],
#   ['with', 'O'],
#   ['Taiwan', 'LOC'],
#   [',', 'O'],
#   ['which', 'O'],
#   ['Beijing', 'LOC'],
#   ['considers', 'O'],
#   ['a', 'O'],
#   ['renegade', 'O'],
#   ['province', 'O'],
#   ['.', 'O']],
#  [['China', 'LOC'],
#   [',', 'O'],
#   ['which', 'O'],
#   ['has', 'O'],
#   ['long', 'O'],
#   ['opposed', 'O'],
#   ['all', 'O'],
#   ['Taipei', 'LOC'],
#   ['efforts', 'O'],
#   ['to', 'O'],
#   ['gain', 'O'],
#   ['greater', 'O'],
#   ['international', 'O'],
#   ['recognition', 'O'],
#   [',', 'O'],
#   ['was', 'O'],
#   ['infuriated', 'O'],
#   ['by', 'O'],
#   ['a', 'O'],
#   ['visit', 'O'],
#   ['to', 'O'],
#   ['Ukraine', 'LOC'],
#   ['this', 'O'],
#   ['week', 'O'],
#   ['by', 'O'],
#   ['Taiwanese', 'MISC'],
#   ['Vice', 'O'],
#   ['President', 'O'],
#   ['Lien', 'PER'],
#   ['.', 'O']],
#  [['China', 'LOC'],
#   ['says', 'O'],
#   ['time', 'O'],
#   ['right', 'O'],
#   ['for', 'O'],
#   ['Taiwan', 'LOC'],
#   ['talks', 'O'],
#   ['.', 'O']],
#  [['BEIJING', 'LOC'], ['1996-08-22', 'O']],
#  [['China', 'LOC'],
#   ['has', 'O'],
#   ['said', 'O'],
#   ['it', 'O'],
#   ['was', 'O'],
#   ['time', 'O'],
#   ['for', 'O'],
#   ['political', 'O'],
#   ['talks', 'O'],
#   ['with', 'O'],
#   ['Taiwan', 'LOC'],
#   ['and', 'O'],
#   ['that', 'O'],
#   ['the', 'O'],
#   ['rival', 'O'],
#   ['island', 'O'],
#   ['should', 'O'],
#   ['take', 'O'],
#   ['practical', 'O'],
#   ['steps', 'O'],
#   ['towards', 'O'],
#   ['that', 'O'],
#   ['goal', 'O'],
#   ['.', 'O']],
#  [['Consultations', 'O'],
#   ['should', 'O'],
#   ['be', 'O'],
#   ['held', 'O'],
#   ['to', 'O'],
#   ['set', 'O'],
#   ['the', 'O'],
#   ['time', 'O'],
#   ['and', 'O'],
#   ['format', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['talks', 'O'],
#   [',', 'O'],
#   ['the', 'O'],
#   ['official', 'O'],
#   ['Xinhua', 'ORG'],
#   ['news', 'O'],
#   ['agency', 'O'],
#   ['quoted', 'O'],
#   ['Tang', 'PER'],
#   ['Shubei', 'PER'],
#   [',', 'O'],
#   ['executive', 'O'],
#   ['vice', 'O'],
#   ['chairman', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['Association', 'ORG'],
#   ['for', 'ORG'],
#   ['Relations', 'ORG'],
#   ['Across', 'ORG'],
#   ['the', 'ORG'],
#   ['Taiwan', 'ORG'],
#   ['Straits', 'ORG'],
#   [',', 'O'],
#   ['as', 'O'],
#   ['saying', 'O'],
#   ['late', 'O'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['.', 'O']],
#  [['German', 'MISC'],
#   ['July', 'O'],
#   ['car', 'O'],
#   ['registrations', 'O'],
#   ['up', 'O'],
#   ['14.2', 'O'],
#   ['pct', 'O'],
#   ['yr', 'O'],
#   ['/', 'O'],
#   ['yr', 'O'],
#   ['.', 'O']],
#  [['FRANKFURT', 'LOC'], ['1996-08-22', 'O']],
#  [['German', 'MISC'],
#   ['first-time', 'O'],
#   ['registrations', 'O'],
#   ['of', 'O'],
#   ['motor', 'O'],
#   ['vehicles', 'O'],
#   ['jumped', 'O'],
#   ['14.2', 'O'],
#   ['percent', 'O'],
#   ['in', 'O'],
#   ['July', 'O'],
#   ['this', 'O'],
#   ['year', 'O'],
#   ['from', 'O'],
#   ['the', 'O'],
#   ['year-earlier', 'O'],
#   ['period', 'O'],
#   [',', 'O'],
#   ['the', 'O'],
#   ['Federal', 'ORG'],
#   ['office', 'ORG'],
#   ['for', 'ORG'],
#   ['motor', 'ORG'],
#   ['vehicles', 'ORG'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['office', 'O'],
#   ['said', 'O'],
#   ['356,725', 'O'],
#   ['new', 'O'],
#   ['cars', 'O'],
#   ['were', 'O'],
#   ['registered', 'O'],
#   ['in', 'O'],
#   ['July', 'O'],
#   ['1996', 'O'],
#   ['--', 'O'],
#   ['304,850', 'O'],
#   ['passenger', 'O'],
#   ['cars', 'O'],
#   ['and', 'O'],
#   ['15,613', 'O'],
#   ['trucks', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['figures', 'O'],
#   ['represent', 'O'],
#   ['a', 'O'],
#   ['13.6', 'O'],
#   ['percent', 'O'],
#   ['increase', 'O'],
#   ['for', 'O'],
#   ['passenger', 'O'],
#   ['cars', 'O'],
#   ['and', 'O'],
#   ['a', 'O'],
#   ['2.2', 'O'],
#   ['percent', 'O'],
#   ['decline', 'O'],
#   ['for', 'O'],
#   ['trucks', 'O'],
#   ['from', 'O'],
#   ['July', 'O'],
#   ['1995', 'O'],
#   ['.', 'O']],
#  [['Motor-bike', 'O'],
#   ['registration', 'O'],
#   ['rose', 'O'],
#   ['32.7', 'O'],
#   ['percent', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['period', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['growth', 'O'],
#   ['was', 'O'],
#   ['partly', 'O'],
#   ['due', 'O'],
#   ['to', 'O'],
#   ['an', 'O'],
#   ['increased', 'O'],
#   ['number', 'O'],
#   ['of', 'O'],
#   ['Germans', 'MISC'],
#   ['buying', 'O'],
#   ['German', 'MISC'],
#   ['cars', 'O'],
#   ['abroad', 'O'],
#   [',', 'O'],
#   ['while', 'O'],
#   ['manufacturers', 'O'],
#   ['said', 'O'],
#   ['that', 'O'],
#   ['domestic', 'O'],
#   ['demand', 'O'],
#   ['was', 'O'],
#   ['weak', 'O'],
#   [',', 'O'],
#   ['the', 'O'],
#   ['federal', 'O'],
#   ['office', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['Almost', 'O'],
#   ['all', 'O'],
#   ['German', 'MISC'],
#   ['car', 'O'],
#   ['manufacturers', 'O'],
#   ['posted', 'O'],
#   ['gains', 'O'],
#   ['in', 'O'],
#   ['registration', 'O'],
#   ['numbers', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['period', 'O'],
#   ['.', 'O']],
#  [['Volkswagen', 'ORG'],
#   ['AG', 'ORG'],
#   ['won', 'O'],
#   ['77,719', 'O'],
#   ['registrations', 'O'],
#   [',', 'O'],
#   ['slightly', 'O'],
#   ['more', 'O'],
#   ['than', 'O'],
#   ['a', 'O'],
#   ['quarter', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['total', 'O'],
#   ['.', 'O']],
#  [['Opel', 'ORG'],
#   ['AG', 'ORG'],
#   ['together', 'O'],
#   ['with', 'O'],
#   ['General', 'ORG'],
#   ['Motors', 'ORG'],
#   ['came', 'O'],
#   ['in', 'O'],
#   ['second', 'O'],
#   ['place', 'O'],
#   ['with', 'O'],
#   ['49,269', 'O'],
#   ['registrations', 'O'],
#   [',', 'O'],
#   ['16.4', 'O'],
#   ['percent', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['overall', 'O'],
#   ['figure', 'O'],
#   ['.', 'O']],
#  [['Third', 'O'],
#   ['was', 'O'],
#   ['Ford', 'ORG'],
#   ['with', 'O'],
#   ['35,563', 'O'],
#   ['registrations', 'O'],
#   [',', 'O'],
#   ['or', 'O'],
#   ['11.7', 'O'],
#   ['percent', 'O'],
#   ['.', 'O']],
#  [['Only', 'O'],
#   ['Seat', 'ORG'],
#   ['and', 'O'],
#   ['Porsche', 'ORG'],
#   ['had', 'O'],
#   ['fewer', 'O'],
#   ['registrations', 'O'],
#   ['in', 'O'],
#   ['July', 'O'],
#   ['1996', 'O'],
#   ['compared', 'O'],
#   ['to', 'O'],
#   ['last', 'O'],
#   ['year', 'O'],
#   ["'s", 'O'],
#   ['July', 'O'],
#   ['.', 'O']],
#  [['Seat', 'ORG'],
#   ['posted', 'O'],
#   ['3,420', 'O'],
#   ['registrations', 'O'],
#   ['compared', 'O'],
#   ['with', 'O'],
#   ['5522', 'O'],
#   ['registrations', 'O'],
#   ['in', 'O'],
#   ['July', 'O'],
#   ['a', 'O'],
#   ['year', 'O'],
#   ['earlier', 'O'],
#   ['.', 'O']],
#  [['Porsche', 'ORG'],
#   ["'s", 'O'],
#   ['registrations', 'O'],
#   ['fell', 'O'],
#   ['to', 'O'],
#   ['554', 'O'],
#   ['from', 'O'],
#   ['643', 'O'],
#   ['.', 'O']],
#  [['GREEK', 'MISC'],
#   ['SOCIALISTS', 'O'],
#   ['GIVE', 'O'],
#   ['GREEN', 'O'],
#   ['LIGHT', 'O'],
#   ['TO', 'O'],
#   ['PM', 'O'],
#   ['FOR', 'O'],
#   ['ELECTIONS', 'O'],
#   ['.', 'O']],
#  [['ATHENS', 'LOC'], ['1996-08-22', 'O']],
#  [['The', 'O'],
#   ['Greek', 'MISC'],
#   ['socialist', 'O'],
#   ['party', 'O'],
#   ["'s", 'O'],
#   ['executive', 'O'],
#   ['bureau', 'O'],
#   ['gave', 'O'],
#   ['the', 'O'],
#   ['green', 'O'],
#   ['light', 'O'],
#   ['to', 'O'],
#   ['Prime', 'O'],
#   ['Minister', 'O'],
#   ['Costas', 'PER'],
#   ['Simitis', 'PER'],
#   ['to', 'O'],
#   ['call', 'O'],
#   ['snap', 'O'],
#   ['elections', 'O'],
#   [',', 'O'],
#   ['its', 'O'],
#   ['general', 'O'],
#   ['secretary', 'O'],
#   ['Costas', 'PER'],
#   ['Skandalidis', 'PER'],
#   ['told', 'O'],
#   ['reporters', 'O'],
#   ['.', 'O']],
#  [['Prime', 'O'],
#   ['Minister', 'O'],
#   ['Costas', 'PER'],
#   ['Simitis', 'PER'],
#   ['is', 'O'],
#   ['going', 'O'],
#   ['to', 'O'],
#   ['make', 'O'],
#   ['an', 'O'],
#   ['official', 'O'],
#   ['announcement', 'O'],
#   ['after', 'O'],
#   ['a', 'O'],
#   ['cabinet', 'O'],
#   ['meeting', 'O'],
#   ['later', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   [',', 'O'],
#   ['said', 'O'],
#   ['Skandalidis', 'PER'],
#   ['.', 'O']],
#  [['--', 'O'],
#   ['Dimitris', 'PER'],
#   ['Kontogiannis', 'PER'],
#   [',', 'O'],
#   ['Athens', 'ORG'],
#   ['Newsroom', 'ORG'],
#   ['+301', 'O'],
#   ['3311812-4', 'O']],
#  [['BayerVB', 'ORG'],
#   ['sets', 'O'],
#   ['C$', 'MISC'],
#   ['100', 'O'],
#   ['million', 'O'],
#   ['six-year', 'O'],
#   ['bond', 'O'],
#   ['.', 'O']],
#  [['LONDON', 'LOC'], ['1996-08-22', 'O']],
#  [['The', 'O'],
#   ['following', 'O'],
#   ['bond', 'O'],
#   ['was', 'O'],
#   ['announced', 'O'],
#   ['by', 'O'],
#   ['lead', 'O'],
#   ['manager', 'O'],
#   ['Toronto', 'PER'],
#   ['Dominion', 'PER'],
#   ['.', 'O']],
#  [['BORROWER', 'O'], ['BAYERISCHE', 'ORG'], ['VEREINSBANK', 'ORG']],
#  [['AMT', 'O'],
#   ['C$', 'MISC'],
#   ['100', 'O'],
#   ['MLN', 'O'],
#   ['COUPON', 'O'],
#   ['6.625', 'O'],
#   ['MATURITY', 'O'],
#   ['24.SEP.02', 'O']],
#  [['TYPE', 'O'],
#   ['STRAIGHT', 'O'],
#   ['ISS', 'O'],
#   ['PRICE', 'O'],
#   ['100.92', 'O'],
#   ['PAY', 'O'],
#   ['DATE', 'O'],
#   ['24.SEP.96', 'O']],
#  [['FULL', 'O'],
#   ['FEES', 'O'],
#   ['1.875', 'O'],
#   ['REOFFER', 'O'],
#   ['99.32', 'O'],
#   ['SPREAD', 'O'],
#   ['+20', 'O'],
#   ['BP', 'O']],
#  [['MOODY', 'O'],
#   ['AA1', 'O'],
#   ['LISTING', 'O'],
#   ['LUX', 'O'],
#   ['PAY', 'O'],
#   ['FREQ', 'O'],
#   ['=', 'O']],
#  [['S&P', 'ORG'],
#   ['=', 'O'],
#   ['DENOMS', 'O'],
#   ['(', 'O'],
#   ['K', 'O'],
#   [')', 'O'],
#   ['1-10-100', 'O'],
#   ['SALE', 'O'],
#   ['LIMITS', 'O'],
#   ['US', 'LOC'],
#   ['/', 'O'],
#   ['UK', 'LOC'],
#   ['/', 'O'],
#   ['CA', 'LOC']],
#  [['NEG', 'O'],
#   ['PLG', 'O'],
#   ['NO', 'O'],
#   ['CRS', 'O'],
#   ['DEFLT', 'O'],
#   ['NO', 'O'],
#   ['FORCE', 'O'],
#   ['MAJ', 'O'],
#   ['=', 'O']],
#  [['GOV', 'O'],
#   ['LAW', 'O'],
#   ['GERMAN', 'MISC'],
#   ['HOME', 'O'],
#   ['CTRY', 'O'],
#   ['=', 'O'],
#   ['TAX', 'O'],
#   ['PROVS', 'O'],
#   ['STANDARD', 'O']],
#  [['MGT', 'O'],
#   ['/', 'O'],
#   ['UND', 'O'],
#   ['0.275', 'O'],
#   ['SELL', 'O'],
#   ['CONC', 'O'],
#   ['1.60', 'O'],
#   ['PRAECIP', 'O'],
#   ['=', 'O']],
#  [['UNDERLYING', 'O'],
#   ['GOVT', 'O'],
#   ['BOND', 'O'],
#   ['7.0', 'O'],
#   ['PCT', 'O'],
#   ['SEPT', 'O'],
#   ['2001', 'O']],
#  [['NOTES', 'O'],
#   ['BAYERISCHE', 'ORG'],
#   ['VEREINSBANK', 'ORG'],
#   ['IS', 'O'],
#   ['JOINT', 'O'],
#   ['LEAD', 'O'],
#   ['MANAGER', 'O']],
#  [['--', 'O'],
#   ['London', 'ORG'],
#   ['Newsroom', 'ORG'],
#   ['+44', 'O'],
#   ['171', 'O'],
#   ['542', 'O'],
#   ['7658', 'O']],
#  [['Venantius', 'ORG'],
#   ['sets', 'O'],
#   ['$', 'O'],
#   ['300', 'O'],
#   ['million', 'O'],
#   ['January', 'O'],
#   ['1999', 'O'],
#   ['FRN', 'O'],
#   ['.', 'O']],
#  [['LONDON', 'LOC'], ['1996-08-22', 'O']],
#  [['The', 'O'],
#   ['following', 'O'],
#   ['floating-rate', 'O'],
#   ['issue', 'O'],
#   ['was', 'O'],
#   ['announced', 'O'],
#   ['by', 'O'],
#   ['lead', 'O'],
#   ['manager', 'O'],
#   ['Lehman', 'ORG'],
#   ['Brothers', 'ORG'],
#   ['International', 'ORG'],
#   ['.', 'O']],
#  [['BORROWER', 'O'],
#   ['VENANTIUS', 'ORG'],
#   ['AB', 'ORG'],
#   ['(', 'O'],
#   ['SWEDISH', 'MISC'],
#   ['NATIONAL', 'O'],
#   ['MORTGAGE', 'O'],
#   ['AGENCY', 'O'],
#   [')', 'O']],
#  [['AMT', 'O'],
#   ['$', 'O'],
#   ['300', 'O'],
#   ['MLN', 'O'],
#   ['SPREAD', 'O'],
#   ['-', 'O'],
#   ['12.5', 'O'],
#   ['BP', 'O'],
#   ['MATURITY', 'O'],
#   ['21.JAN.99', 'O']],
#  [['TYPE', 'O'],
#   ['FRN', 'O'],
#   ['BASE', 'O'],
#   ['3M', 'ORG'],
#   ['LIBOR', 'O'],
#   ['PAY', 'O'],
#   ['DATE', 'O'],
#   ['S23.SEP.96', 'O']],
#  [['LAST', 'O'],
#   ['MOODY', 'O'],
#   ['AA3', 'O'],
#   ['ISS', 'O'],
#   ['PRICE', 'O'],
#   ['99.956', 'O'],
#   ['FULL', 'O'],
#   ['FEES', 'O'],
#   ['10', 'O'],
#   ['BP', 'O']],
#  [['LAST', 'O'], ['S&P', 'ORG'], ['AA+', 'O'], ['REOFFER', 'O'], ['=', 'O']],
#  [['NOTES', 'O'], ['S', 'O'], ['SHORT', 'O'], ['FIRST', 'O'], ['COUPON', 'O']],
#  [['LISTING', 'O'],
#   ['LONDON', 'LOC'],
#   ['DENOMS', 'O'],
#   ['(', 'O'],
#   ['K', 'O'],
#   [')', 'O'],
#   ['1-10-100', 'O'],
#   ['SALE', 'O'],
#   ['LIMITS', 'O'],
#   ['US', 'LOC'],
#   ['/', 'O'],
#   ['UK', 'LOC'],
#   ['/', 'O'],
#   ['JP', 'LOC'],
#   ['/', 'O'],
#   ['FR', 'LOC']],
#  [['NEG', 'O'],
#   ['PLG', 'O'],
#   ['YES', 'O'],
#   ['CRS', 'O'],
#   ['DEFLT', 'O'],
#   ['NO', 'O'],
#   ['FORCE', 'O'],
#   ['MAJ', 'O'],
#   ['IPMA', 'O'],
#   ['2', 'O']],
#  [['GOV', 'O'],
#   ['LAW', 'O'],
#   ['ENGLISH', 'MISC'],
#   ['HOME', 'O'],
#   ['CTRY', 'O'],
#   ['SWEDEN', 'LOC'],
#   ['TAX', 'O'],
#   ['PROVS', 'O'],
#   ['STANDARD', 'O']],
#  [['MGT', 'O'],
#   ['/', 'O'],
#   ['UND', 'O'],
#   ['5', 'O'],
#   ['BP', 'O'],
#   ['SELL', 'O'],
#   ['CONC', 'O'],
#   ['5', 'O'],
#   ['BP', 'O'],
#   ['PRAECIP', 'O'],
#   ['=', 'O']],
#  [['NOTES', 'O'],
#   ['ISSUED', 'O'],
#   ['OFF', 'O'],
#   ['EMTN', 'O'],
#   ['PROGRAMME', 'O']],
#  [['--', 'O'],
#   ['London', 'ORG'],
#   ['Newsroom', 'ORG'],
#   ['+44', 'O'],
#   ['171', 'O'],
#   ['542', 'O'],
#   ['8863', 'O']],
#  [['Port', 'O'],
#   ['conditions', 'O'],
#   ['update', 'O'],
#   ['-', 'O'],
#   ['Syria', 'LOC'],
#   ['-', 'O'],
#   ['Lloyds', 'ORG'],
#   ['Shipping', 'ORG'],
#   ['.', 'O']],
#  [['Port', 'O'],
#   ['conditions', 'O'],
#   ['from', 'O'],
#   ['Lloyds', 'ORG'],
#   ['Shipping', 'ORG'],
#   ['Intelligence', 'ORG'],
#   ['Service', 'ORG'],
#   ['--', 'O']],
#  [['LATTAKIA', 'LOC'],
#   [',', 'O'],
#   ['Aug', 'O'],
#   ['10', 'O'],
#   ['-', 'O'],
#   ['waiting', 'O'],
#   ['time', 'O'],
#   ['at', 'O'],
#   ['Lattakia', 'LOC'],
#   ['and', 'O'],
#   ['Tartous', 'LOC'],
#   ['presently', 'O'],
#   ['24', 'O'],
#   ['hours', 'O'],
#   ['.', 'O']],
#  [['Israel', 'LOC'],
#   ['plays', 'O'],
#   ['down', 'O'],
#   ['fears', 'O'],
#   ['of', 'O'],
#   ['war', 'O'],
#   ['with', 'O'],
#   ['Syria', 'LOC'],
#   ['.', 'O']],
#  [['Colleen', 'PER'], ['Siegel', 'PER']],
#  [['JERUSALEM', 'LOC'], ['1996-08-22', 'O']],
#  [['Israel', 'LOC'],
#   ["'s", 'O'],
#   ['outgoing', 'O'],
#   ['peace', 'O'],
#   ['negotiator', 'O'],
#   ['with', 'O'],
#   ['Syria', 'LOC'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['current', 'O'],
#   ['tensions', 'O'],
#   ['between', 'O'],
#   ['the', 'O'],
#   ['two', 'O'],
#   ['countries', 'O'],
#   ['appeared', 'O'],
#   ['to', 'O'],
#   ['be', 'O'],
#   ['a', 'O'],
#   ['storm', 'O'],
#   ['in', 'O'],
#   ['a', 'O'],
#   ['teacup', 'O'],
#   ['.', 'O']],
#  [['Itamar', 'PER'],
#   ['Rabinovich', 'PER'],
#   [',', 'O'],
#   ['who', 'O'],
#   ['as', 'O'],
#   ['Israel', 'LOC'],
#   ["'s", 'O'],
#   ['ambassador', 'O'],
#   ['to', 'O'],
#   ['Washington', 'LOC'],
#   ['conducted', 'O'],
#   ['unfruitful', 'O'],
#   ['negotiations', 'O'],
#   ['with', 'O'],
#   ['Syria', 'LOC'],
#   [',', 'O'],
#   ['told', 'O'],
#   ['Israel', 'ORG'],
#   ['Radio', 'ORG'],
#   ['it', 'O'],
#   ['looked', 'O'],
#   ['like', 'O'],
#   ['Damascus', 'LOC'],
#   ['wanted', 'O'],
#   ['to', 'O'],
#   ['talk', 'O'],
#   ['rather', 'O'],
#   ['than', 'O'],
#   ['fight', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['It', 'O'],
#   ['appears', 'O'],
#   ['to', 'O'],
#   ['me', 'O'],
#   ['the', 'O'],
#   ['Syrian', 'MISC'],
#   ['priority', 'O'],
#   ['is', 'O'],
#   ['still', 'O'],
#   ['to', 'O'],
#   ['negotiate', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['Syrians', 'MISC'],
#   ['are', 'O'],
#   ['confused', 'O'],
#   [',', 'O'],
#   ['they', 'O'],
#   ['are', 'O'],
#   ['definitely', 'O'],
#   ['tense', 'O'],
#   [',', 'O'],
#   ['but', 'O'],
#   ['the', 'O'],
#   ['general', 'O'],
#   ['assessment', 'O'],
#   ['here', 'O'],
#   ['in', 'O'],
#   ['Washington', 'LOC'],
#   ['is', 'O'],
#   ['that', 'O'],
#   ['this', 'O'],
#   ['is', 'O'],
#   ['essentially', 'O'],
#   ['a', 'O'],
#   ['storm', 'O'],
#   ['in', 'O'],
#   ['a', 'O'],
#   ['teacup', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['he', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['Rabinovich', 'PER'],
#   ['is', 'O'],
#   ['winding', 'O'],
#   ['up', 'O'],
#   ['his', 'O'],
#   ['term', 'O'],
#   ['as', 'O'],
#   ['ambassador', 'O'],
#   ['.', 'O']],
#  [['He', 'O'],
#   ['will', 'O'],
#   ['be', 'O'],
#   ['replaced', 'O'],
#   ['by', 'O'],
#   ['Eliahu', 'PER'],
#   ['Ben-Elissar', 'PER'],
#   [',', 'O'],
#   ['a', 'O'],
#   ['former', 'O'],
#   ['Israeli', 'MISC'],
#   ['envoy', 'O'],
#   ['to', 'O'],
#   ['Egypt', 'LOC'],
#   ['and', 'O'],
#   ['right-wing', 'O'],
#   ['Likud', 'ORG'],
#   ['party', 'O'],
#   ['politician', 'O'],
#   ['.', 'O']],
#  [['Israel', 'LOC'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['sent', 'O'],
#   ['Syria', 'LOC'],
#   ['a', 'O'],
#   ['message', 'O'],
#   [',', 'O'],
#   ['via', 'O'],
#   ['Washington', 'LOC'],
#   [',', 'O'],
#   ['saying', 'O'],
#   ['it', 'O'],
#   ['was', 'O'],
#   ['committed', 'O'],
#   ['to', 'O'],
#   ['peace', 'O'],
#   ['and', 'O'],
#   ['wanted', 'O'],
#   ['to', 'O'],
#   ['open', 'O'],
#   ['negotiations', 'O'],
#   ['without', 'O'],
#   ['preconditions', 'O'],
#   ['.', 'O']],
#  [['But', 'O'],
#   ['it', 'O'],
#   ['slammed', 'O'],
#   ['Damascus', 'LOC'],
#   ['for', 'O'],
#   ['creating', 'O'],
#   ['what', 'O'],
#   ['it', 'O'],
#   ['called', 'O'],
#   ['a', 'O'],
#   ['dangerous', 'O'],
#   ['atmosphere', 'O'],
#   ['.', 'O']],
#  [['Syria', 'LOC'],
#   ['accused', 'O'],
#   ['Israel', 'LOC'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['of', 'O'],
#   ['launching', 'O'],
#   ['a', 'O'],
#   ['hysterical', 'O'],
#   ['campaign', 'O'],
#   ['against', 'O'],
#   ['it', 'O'],
#   ['after', 'O'],
#   ['Israeli', 'MISC'],
#   ['television', 'O'],
#   ['reported', 'O'],
#   ['that', 'O'],
#   ['Damascus', 'LOC'],
#   ['had', 'O'],
#   ['recently', 'O'],
#   ['test', 'O'],
#   ['fired', 'O'],
#   ['a', 'O'],
#   ['missile', 'O'],
#   ['.', 'O']],
#  [['It', 'O'],
#   ['said', 'O'],
#   ['its', 'O'],
#   ['arms', 'O'],
#   ['purchases', 'O'],
#   ['were', 'O'],
#   ['for', 'O'],
#   ['defensive', 'O'],
#   ['purposes', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['The', 'O'],
#   ['message', 'O'],
#   ['that', 'O'],
#   ['we', 'O'],
#   ['sent', 'O'],
#   ['to', 'O'],
#   ['(', 'O'],
#   ['Syrian', 'MISC'],
#   ['President', 'O'],
#   ['Hafez', 'PER'],
#   ['al-', 'PER'],
#   [')', 'O'],
#   ['Assad', 'PER'],
#   ['is', 'O'],
#   ['that', 'O'],
#   ['Israel', 'LOC'],
#   ['is', 'O'],
#   ['ready', 'O'],
#   ['at', 'O'],
#   ['any', 'O'],
#   ['time', 'O'],
#   ['without', 'O'],
#   ['preconditions', 'O'],
#   ['to', 'O'],
#   ['enter', 'O'],
#   ['peace', 'O'],
#   ['negotiations', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['Israeli', 'MISC'],
#   ['Foreign', 'O'],
#   ['Minister', 'O'],
#   ['David', 'PER'],
#   ['Levy', 'PER'],
#   ['told', 'O'],
#   ['Israel', 'ORG'],
#   ['Radio', 'ORG'],
#   ['in', 'O'],
#   ['an', 'O'],
#   ['interview', 'O'],
#   ['.', 'O']],
#  [['Tension', 'O'],
#   ['has', 'O'],
#   ['mounted', 'O'],
#   ['since', 'O'],
#   ['Israeli', 'MISC'],
#   ['Prime', 'O'],
#   ['Minister', 'O'],
#   ['Benjamin', 'PER'],
#   ['Netanyahu', 'PER'],
#   ['took', 'O'],
#   ['office', 'O'],
#   ['in', 'O'],
#   ['June', 'O'],
#   ['vowing', 'O'],
#   ['to', 'O'],
#   ['retain', 'O'],
#   ['the', 'O'],
#   ['Golan', 'LOC'],
#   ['Heights', 'LOC'],
#   ['Israel', 'LOC'],
#   ['captured', 'O'],
#   ['from', 'O'],
#   ['Syria', 'LOC'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['1967', 'O'],
#   ['Middle', 'LOC'],
#   ['East', 'LOC'],
#   ['war', 'O'],
#   ['.', 'O']],
#  [['Israeli-Syrian', 'MISC'],
#   ['peace', 'O'],
#   ['talks', 'O'],
#   ['have', 'O'],
#   ['been', 'O'],
#   ['deadlocked', 'O'],
#   ['over', 'O'],
#   ['the', 'O'],
#   ['Golan', 'LOC'],
#   ['since', 'O'],
#   ['1991', 'O'],
#   ['despite', 'O'],
#   ['the', 'O'],
#   ['previous', 'O'],
#   ['government', 'O'],
#   ["'s", 'O'],
#   ['willingness', 'O'],
#   ['to', 'O'],
#   ['make', 'O'],
#   ['Golan', 'LOC'],
#   ['concessions', 'O'],
#   ['.', 'O']],
#  [['Peace', 'O'],
#   ['talks', 'O'],
#   ['between', 'O'],
#   ['the', 'O'],
#   ['two', 'O'],
#   ['sides', 'O'],
#   ['were', 'O'],
#   ['last', 'O'],
#   ['held', 'O'],
#   ['in', 'O'],
#   ['February', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['The', 'O'],
#   ['voices', 'O'],
#   ['coming', 'O'],
#   ['out', 'O'],
#   ['of', 'O'],
#   ['Damascus', 'LOC'],
#   ['are', 'O'],
#   ['bad', 'O'],
#   [',', 'O'],
#   ['not', 'O'],
#   ['good', 'O'],
#   ['.', 'O']],
#  [['The', 'O'], ['media', 'O'], ['...', 'O']],
#  [['are', 'O'],
#   ['full', 'O'],
#   ['of', 'O'],
#   ['expressions', 'O'],
#   ['and', 'O'],
#   ['declarations', 'O'],
#   ['that', 'O'],
#   ['must', 'O'],
#   ['be', 'O'],
#   ['worrying', 'O'],
#   ['...', 'O']],
#  [['this', 'O'],
#   ['artificial', 'O'],
#   ['atmosphere', 'O'],
#   ['is', 'O'],
#   ['very', 'O'],
#   ['dangerous', 'O'],
#   ['because', 'O'],
#   ['those', 'O'],
#   ['who', 'O'],
#   ['spread', 'O'],
#   ['it', 'O'],
#   ['could', 'O'],
#   ['become', 'O'],
#   ['its', 'O'],
#   ['prisoners', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['Levy', 'PER'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['We', 'O'],
#   ['expect', 'O'],
#   ['from', 'O'],
#   ['Syria', 'LOC'],
#   [',', 'O'],
#   ['if', 'O'],
#   ['its', 'O'],
#   ['face', 'O'],
#   ['is', 'O'],
#   ['to', 'O'],
#   ['peace', 'O'],
#   [',', 'O'],
#   ['that', 'O'],
#   ['it', 'O'],
#   ['will', 'O'],
#   ['answer', 'O'],
#   ['Israel', 'LOC'],
#   ["'s", 'O'],
#   ['message', 'O'],
#   ['to', 'O'],
#   ['enter', 'O'],
#   ['peace', 'O'],
#   ['negotiations', 'O'],
#   ['because', 'O'],
#   ['that', 'O'],
#   ['is', 'O'],
#   ['our', 'O'],
#   ['goal', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['he', 'O'],
#   ['said', 'O'],
#   ['.', 'O'],
#   ['"', 'O']],
#  [['We', 'O'],
#   ['do', 'O'],
#   ['not', 'O'],
#   ['want', 'O'],
#   ['a', 'O'],
#   ['war', 'O'],
#   [',', 'O'],
#   ['God', 'PER'],
#   ['forbid', 'O'],
#   ['.', 'O']],
#  [['No', 'O'],
#   ['one', 'O'],
#   ['benefits', 'O'],
#   ['from', 'O'],
#   ['wars', 'O'],
#   ['.', 'O'],
#   ['"', 'O']],
#  [['Israel', 'LOC'],
#   ["'s", 'O'],
#   ['Channel', 'ORG'],
#   ['Two', 'ORG'],
#   ['television', 'O'],
#   ['said', 'O'],
#   ['Damascus', 'LOC'],
#   ['had', 'O'],
#   ['sent', 'O'],
#   ['a', 'O'],
#   ['"', 'O'],
#   ['calming', 'O'],
#   ['signal', 'O'],
#   ['"', 'O'],
#   ['to', 'O'],
#   ['Israel', 'LOC'],
#   ['.', 'O']],
#  [['It', 'O'],
#   ['gave', 'O'],
#   ['no', 'O'],
#   ['source', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['report', 'O'],
#   ['.', 'O']],
#  [['Netanyahu', 'PER'],
#   ['and', 'O'],
#   ['Levy', 'PER'],
#   ["'s", 'O'],
#   ['spokesmen', 'O'],
#   ['said', 'O'],
#   ['they', 'O'],
#   ['could', 'O'],
#   ['not', 'O'],
#   ['confirm', 'O'],
#   ['it', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['television', 'O'],
#   ['also', 'O'],
#   ['said', 'O'],
#   ['that', 'O'],
#   ['Netanyahu', 'PER'],
#   ['had', 'O'],
#   ['sent', 'O'],
#   ['messages', 'O'],
#   ['to', 'O'],
#   ['reassure', 'O'],
#   ['Syria', 'LOC'],
#   ['via', 'O'],
#   ['Cairo', 'LOC'],
#   [',', 'O'],
#   ['the', 'O'],
#   ['United', 'LOC'],
#   ['States', 'LOC'],
#   ['and', 'O'],
#   ['Moscow', 'LOC'],
#   ['.', 'O']],
#  [['Polish', 'MISC'],
#   ['diplomat', 'O'],
#   ['denies', 'O'],
#   ['nurses', 'O'],
#   ['stranded', 'O'],
#   ['in', 'O'],
#   ['Libya', 'LOC'],
#   ['.', 'O']],
#  [['TUNIS', 'LOC'], ['1996-08-22', 'O']],
#  [['A', 'O'],
#   ['Polish', 'MISC'],
#   ['diplomat', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['denied', 'O'],
#   ['a', 'O'],
#   ['Polish', 'MISC'],
#   ['tabloid', 'O'],
#   ['report', 'O'],
#   ['this', 'O'],
#   ['week', 'O'],
#   ['that', 'O'],
#   ['Libya', 'LOC'],
#   ['was', 'O'],
#   ['refusing', 'O'],
#   ['exit', 'O'],
#   ['visas', 'O'],
#   ['to', 'O'],
#   ['100', 'O'],
#   ['Polish', 'MISC'],
#   ['nurses', 'O'],
#   ['trying', 'O'],
#   ['to', 'O'],
#   ['return', 'O'],
#   ['home', 'O'],
#   ['after', 'O'],
#   ['working', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['North', 'MISC'],
#   ['African', 'MISC'],
#   ['country', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['This', 'O'],
#   ['is', 'O'],
#   ['not', 'O'],
#   ['true', 'O'],
#   ['.', 'O']],
#  [['Up', 'O'],
#   ['to', 'O'],
#   ['today', 'O'],
#   [',', 'O'],
#   ['we', 'O'],
#   ['have', 'O'],
#   ['no', 'O'],
#   ['knowledge', 'O'],
#   ['of', 'O'],
#   ['any', 'O'],
#   ['nurse', 'O'],
#   ['stranded', 'O'],
#   ['or', 'O'],
#   ['kept', 'O'],
#   ['in', 'O'],
#   ['Libya', 'LOC'],
#   ['without', 'O'],
#   ['her', 'O'],
#   ['will', 'O'],
#   [',', 'O'],
#   ['and', 'O'],
#   ['we', 'O'],
#   ['have', 'O'],
#   ['not', 'O'],
#   ['received', 'O'],
#   ['any', 'O'],
#   ['complaint', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['the', 'O'],
#   ['Polish', 'MISC'],
#   ['embassy', 'O'],
#   ["'s", 'O'],
#   ['charge', 'O'],
#   ["d'affaires", 'O'],
#   ['in', 'O'],
#   ['Tripoli', 'LOC'],
#   [',', 'O'],
#   ['Tadeusz', 'PER'],
#   ['Awdankiewicz', 'PER'],
#   [',', 'O'],
#   ['told', 'O'],
#   ['Reuters', 'ORG'],
#   ['by', 'O'],
#   ['telephone', 'O'],
#   ['.', 'O']],
#  [['Poland', 'LOC'],
#   ["'s", 'O'],
#   ['labour', 'O'],
#   ['ministry', 'O'],
#   ['said', 'O'],
#   ['this', 'O'],
#   ['week', 'O'],
#   ['it', 'O'],
#   ['would', 'O'],
#   ['send', 'O'],
#   ['a', 'O'],
#   ['team', 'O'],
#   ['to', 'O'],
#   ['Libya', 'LOC'],
#   ['to', 'O'],
#   ['investigate', 'O'],
#   [',', 'O'],
#   ['but', 'O'],
#   ['Awdankiewicz', 'PER'],
#   ['said', 'O'],
#   ['the', 'O'],
#   ['probe', 'O'],
#   ['was', 'O'],
#   ['prompted', 'O'],
#   ['by', 'O'],
#   ['some', 'O'],
#   ['nurses', 'O'],
#   ['complaining', 'O'],
#   ['about', 'O'],
#   ['their', 'O'],
#   ['work', 'O'],
#   ['conditions', 'O'],
#   ['such', 'O'],
#   ['as', 'O'],
#   ['non-payment', 'O'],
#   ['of', 'O'],
#   ['their', 'O'],
#   ['salaries', 'O'],
#   ['.', 'O']],
#  [['He', 'O'],
#   ['said', 'O'],
#   ['that', 'O'],
#   ['there', 'O'],
#   ['are', 'O'],
#   ['an', 'O'],
#   ['estimated', 'O'],
#   ['800', 'O'],
#   ['Polish', 'MISC'],
#   ['nurses', 'O'],
#   ['working', 'O'],
#   ['in', 'O'],
#   ['Libya', 'LOC'],
#   ['.', 'O']],
#  [['Two', 'O'],
#   ['Iranian', 'MISC'],
#   ['opposition', 'O'],
#   ['leaders', 'O'],
#   ['meet', 'O'],
#   ['in', 'O'],
#   ['Baghdad', 'LOC'],
#   ['.', 'O']],
#  [['Hassan', 'PER'], ['Hafidh', 'PER']],
#  [['BAGHDAD', 'LOC'], ['1996-08-22', 'O']],
#  [['An', 'O'],
#   ['Iranian', 'MISC'],
#   ['exile', 'O'],
#   ['group', 'O'],
#   ['based', 'O'],
#   ['in', 'O'],
#   ['Iraq', 'LOC'],
#   ['vowed', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['to', 'O'],
#   ['extend', 'O'],
#   ['support', 'O'],
#   ['to', 'O'],
#   ['Iran', 'LOC'],
#   ["'s", 'O'],
#   ['Kurdish', 'MISC'],
#   ['rebels', 'O'],
#   ['after', 'O'],
#   ['they', 'O'],
#   ['were', 'O'],
#   ['attacked', 'O'],
#   ['by', 'O'],
#   ['Iranian', 'MISC'],
#   ['troops', 'O'],
#   ['deep', 'O'],
#   ['inside', 'O'],
#   ['Iraq', 'LOC'],
#   ['last', 'O'],
#   ['month', 'O'],
#   ['.', 'O']],
#  [['A', 'O'],
#   ['Mujahideen', 'ORG'],
#   ['Khalq', 'ORG'],
#   ['statement', 'O'],
#   ['said', 'O'],
#   ['its', 'O'],
#   ['leader', 'O'],
#   ['Massoud', 'PER'],
#   ['Rajavi', 'PER'],
#   ['met', 'O'],
#   ['in', 'O'],
#   ['Baghdad', 'LOC'],
#   ['the', 'O'],
#   ['Secretary-General', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['Kurdistan', 'ORG'],
#   ['Democratic', 'ORG'],
#   ['Party', 'ORG'],
#   ['of', 'ORG'],
#   ['Iran', 'ORG'],
#   ['(', 'O'],
#   ['KDPI', 'ORG'],
#   [')', 'O'],
#   ['Hassan', 'PER'],
#   ['Rastegar', 'PER'],
#   ['on', 'O'],
#   ['Wednesday', 'O'],
#   ['and', 'O'],
#   ['voiced', 'O'],
#   ['his', 'O'],
#   ['support', 'O'],
#   ['to', 'O'],
#   ['Iran', 'LOC'],
#   ["'s", 'O'],
#   ['rebel', 'O'],
#   ['Kurds', 'MISC'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['Rajavi', 'MISC'],
#   ['emphasised', 'O'],
#   ['that', 'O'],
#   ['the', 'O'],
#   ['Iranian', 'MISC'],
#   ['Resistance', 'ORG'],
#   ['would', 'O'],
#   ['continue', 'O'],
#   ['to', 'O'],
#   ['stand', 'O'],
#   ['side', 'O'],
#   ['by', 'O'],
#   ['side', 'O'],
#   ['with', 'O'],
#   ['their', 'O'],
#   ['Kurdish', 'MISC'],
#   ['compatriots', 'O'],
#   ['and', 'O'],
#   ['the', 'O'],
#   ['resistance', 'O'],
#   ['movement', 'O'],
#   ['in', 'O'],
#   ['Iranian', 'LOC'],
#   ['Kurdistan', 'LOC'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['it', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['A', 'O'],
#   ['spokesman', 'O'],
#   ['for', 'O'],
#   ['the', 'O'],
#   ['group', 'O'],
#   ['said', 'O'],
#   ['the', 'O'],
#   ['meeting', 'O'],
#   ['"', 'O'],
#   ['signals', 'O'],
#   ['a', 'O'],
#   ['new', 'O'],
#   ['level', 'O'],
#   ['of', 'O'],
#   ['cooperation', 'O'],
#   ['between', 'O'],
#   ['Mujahideen', 'ORG'],
#   ['Khalq', 'ORG'],
#   ['and', 'O'],
#   ['the', 'O'],
#   ['Iranian', 'MISC'],
#   ['Kurdish', 'MISC'],
#   ['oppositions', 'O'],
#   ['"', 'O'],
#   ['.', 'O']],
#  [['Iran', 'LOC'],
#   ['heavily', 'O'],
#   ['bombarded', 'O'],
#   ['targets', 'O'],
#   ['in', 'O'],
#   ['northern', 'O'],
#   ['Iraq', 'LOC'],
#   ['in', 'O'],
#   ['July', 'O'],
#   ['in', 'O'],
#   ['pursuit', 'O'],
#   ['of', 'O'],
#   ['KDPI', 'ORG'],
#   ['guerrillas', 'O'],
#   ['based', 'O'],
#   ['in', 'O'],
#   ['Iraqi', 'MISC'],
#   ['Kurdish', 'MISC'],
#   ['areas', 'O'],
#   ['outside', 'O'],
#   ['the', 'O'],
#   ['control', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['government', 'O'],
#   ['in', 'O'],
#   ['Baghdad', 'LOC'],
#   ['.', 'O']],
#  [['Iraqi', 'MISC'],
#   ['Kurdish', 'MISC'],
#   ['areas', 'O'],
#   ['bordering', 'O'],
#   ['Iran', 'LOC'],
#   ['are', 'O'],
#   ['under', 'O'],
#   ['the', 'O'],
#   ['control', 'O'],
#   ['of', 'O'],
#   ['guerrillas', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['Iraqi', 'ORG'],
#   ['Kurdish', 'ORG'],
#   ['Patriotic', 'ORG'],
#   ['Union', 'ORG'],
#   ['of', 'ORG'],
#   ['Kurdistan', 'ORG'],
#   ['(', 'O'],
#   ['PUK', 'ORG'],
#   [')', 'O'],
#   ['group', 'O'],
#   ['.', 'O']],
#  [['PUK', 'ORG'],
#   ['and', 'O'],
#   ['Iraq', 'LOC'],
#   ["'s", 'O'],
#   ['Kurdistan', 'ORG'],
#   ['Democratic', 'ORG'],
#   ['Party', 'ORG'],
#   ['(', 'O'],
#   ['KDP', 'ORG'],
#   [')', 'O'],
#   ['the', 'O'],
#   ['two', 'O'],
#   ['main', 'O'],
#   ['Iraqi', 'MISC'],
#   ['Kurdish', 'MISC'],
#   ['factions', 'O'],
#   [',', 'O'],
#   ['have', 'O'],
#   ['had', 'O'],
#   ['northern', 'O'],
#   ['Iraq', 'LOC'],
#   ['under', 'O'],
#   ['their', 'O'],
#   ['control', 'O'],
#   ['since', 'O'],
#   ['Iraqi', 'MISC'],
#   ['forces', 'O'],
#   ['were', 'O'],
#   ['ousted', 'O'],
#   ['from', 'O'],
#   ['Kuwait', 'LOC'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['1991', 'O'],
#   ['Gulf', 'MISC'],
#   ['War', 'MISC'],
#   ['.', 'O']],
#  [['Clashes', 'O'],
#   ['between', 'O'],
#   ['the', 'O'],
#   ['two', 'O'],
#   ['parties', 'O'],
#   ['broke', 'O'],
#   ['out', 'O'],
#   ['at', 'O'],
#   ['the', 'O'],
#   ['weekend', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['most', 'O'],
#   ['serious', 'O'],
#   ['fighting', 'O'],
#   ['since', 'O'],
#   ['a', 'O'],
#   ['U.S.-sponsored', 'MISC'],
#   ['ceasefire', 'O'],
#   ['last', 'O'],
#   ['year', 'O'],
#   ['.', 'O']],
#  [['Mujahideen', 'ORG'],
#   ['Khalq', 'ORG'],
#   ['said', 'O'],
#   ['Iranian', 'MISC'],
#   ['troops', 'O'],
#   ['had', 'O'],
#   ['also', 'O'],
#   ['been', 'O'],
#   ['shelling', 'O'],
#   ['KDP', 'ORG'],
#   ['positions', 'O'],
#   ['in', 'O'],
#   ['Qasri', 'LOC'],
#   ['region', 'O'],
#   ['in', 'O'],
#   ['Suleimaniya', 'LOC'],
#   ['province', 'O'],
#   ['near', 'O'],
#   ['the', 'O'],
#   ['Iranian', 'MISC'],
#   ['border', 'O'],
#   ['over', 'O'],
#   ['the', 'O'],
#   ['last', 'O'],
#   ['two', 'O'],
#   ['days', 'O'],
#   ['.', 'O']],
#  [['It', 'O'],
#   ['said', 'O'],
#   ['about', 'O'],
#   ['100', 'O'],
#   ['Iraqi', 'MISC'],
#   ['Kurds', 'MISC'],
#   ['were', 'O'],
#   ['killed', 'O'],
#   ['or', 'O'],
#   ['wounded', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['attack', 'O'],
#   ['.', 'O']],
#  [['Both', 'O'],
#   ['Iran', 'LOC'],
#   ['and', 'O'],
#   ['Turkey', 'LOC'],
#   ['mount', 'O'],
#   ['air', 'O'],
#   ['and', 'O'],
#   ['land', 'O'],
#   ['strikes', 'O'],
#   ['at', 'O'],
#   ['targets', 'O'],
#   ['in', 'O'],
#   ['northern', 'O'],
#   ['Iraq', 'LOC'],
#   ['in', 'O'],
#   ['pursuit', 'O'],
#   ['of', 'O'],
#   ['their', 'O'],
#   ['own', 'O'],
#   ['Kurdish', 'MISC'],
#   ['rebels', 'O'],
#   ['.', 'O']],
#  [['A', 'O'],
#   ['U.S.-led', 'MISC'],
#   ['air', 'O'],
#   ['force', 'O'],
#   ['in', 'O'],
#   ['southern', 'O'],
#   ['Turkey', 'LOC'],
#   ['protects', 'O'],
#   ['Iraqi', 'MISC'],
#   ['Kurds', 'MISC'],
#   ['from', 'O'],
#   ['possible', 'O'],
#   ['attacks', 'O'],
#   ['by', 'O'],
#   ['Baghdad', 'LOC'],
#   ['troops', 'O'],
#   ['.', 'O']],
#  [['Saudi', 'MISC'],
#   ['riyal', 'O'],
#   ['rates', 'O'],
#   ['steady', 'O'],
#   ['in', 'O'],
#   ['quiet', 'O'],
#   ['summer', 'O'],
#   ['trade', 'O'],
#   ['.', 'O']],
#  [['MANAMA', 'LOC'], ['1996-08-22', 'O']],
#  [['The', 'O'],
#   ['spot', 'O'],
#   ['Saudi', 'MISC'],
#   ['riyal', 'O'],
#   ['against', 'O'],
#   ['the', 'O'],
#   ['dollar', 'O'],
#   ['and', 'O'],
#   ['riyal', 'O'],
#   ['interbank', 'O'],
#   ['deposit', 'O'],
#   ['rates', 'O'],
#   ['were', 'O'],
#   ['mainly', 'O'],
#   ['steady', 'O'],
#   ['this', 'O'],
#   ['week', 'O'],
#   ['in', 'O'],
#   ['quiet', 'O'],
#   ['summer', 'O'],
#   ['trade', 'O'],
#   [',', 'O'],
#   ['dealers', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['kingdom', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['There', 'O'],
#   ['were', 'O'],
#   ['no', 'O'],
#   ['changes', 'O'],
#   ['in', 'O'],
#   ['Saudi', 'MISC'],
#   ['riyal', 'O'],
#   ['rates', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['market', 'O'],
#   ['was', 'O'],
#   ['very', 'O'],
#   ['quiet', 'O'],
#   ['because', 'O'],
#   ['of', 'O'],
#   ['summer', 'O'],
#   ['holidays', 'O'],
#   [',', 'O'],
#   ['"', 'O'],
#   ['one', 'O'],
#   ['dealer', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['spot', 'O'],
#   ['riyal', 'O'],
#   ['was', 'O'],
#   ['put', 'O'],
#   ['at', 'O'],
#   ['3.7504', 'O'],
#   ['/', 'O'],
#   ['06', 'O'],
#   ['to', 'O'],
#   ['the', 'O'],
#   ['dollar', 'O'],
#   ['.', 'O']],
#  [['One-month', 'MISC'],
#   ['interbank', 'O'],
#   ['deposits', 'O'],
#   ['were', 'O'],
#   ['at', 'O'],
#   ['5-1/2', 'O'],
#   [',', 'O'],
#   ['3/8', 'O'],
#   ['percent', 'O'],
#   [',', 'O'],
#   ['three', 'O'],
#   ['months', 'O'],
#   ['were', 'O'],
#   ['5-5/8', 'O'],
#   [',', 'O'],
#   ['1/2', 'O'],
#   ['percent', 'O'],
#   ['and', 'O'],
#   ['six', 'O'],
#   ['months', 'O'],
#   ['were', 'O'],
#   ['5-3/4', 'O'],
#   [',', 'O'],
#   ['5/8', 'O'],
#   ['percent', 'O'],
#   ['.', 'O']],
#  [['One-year', 'MISC'],
#   ['funds', 'O'],
#   ['were', 'O'],
#   ['at', 'O'],
#   ['six', 'O'],
#   [',', 'O'],
#   ['5-7/8', 'O'],
#   ['percent', 'O'],
#   ['.', 'O']],
#  [['Israel', 'LOC'],
#   ['approves', 'O'],
#   ['Arafat', 'PER'],
#   ["'s", 'O'],
#   ['flight', 'O'],
#   ['to', 'O'],
#   ['West', 'LOC'],
#   ['Bank', 'LOC'],
#   ['.', 'O']],
#  [['JERUSALEM', 'LOC'], ['1996-08-22', 'O']],
#  [['Israel', 'LOC'],
#   ['gave', 'O'],
#   ['Palestinian', 'MISC'],
#   ['President', 'O'],
#   ['Yasser', 'PER'],
#   ['Arafat', 'PER'],
#   ['permission', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['to', 'O'],
#   ['fly', 'O'],
#   ['over', 'O'],
#   ['its', 'O'],
#   ['territory', 'O'],
#   ['to', 'O'],
#   ['the', 'O'],
#   ['West', 'LOC'],
#   ['Bank', 'LOC'],
#   [',', 'O'],
#   ['ending', 'O'],
#   ['a', 'O'],
#   ['brief', 'O'],
#   ['Israeli-PLO', 'MISC'],
#   ['crisis', 'O'],
#   [',', 'O'],
#   ['an', 'O'],
#   ['Arafat', 'PER'],
#   ['adviser', 'O'],
#   ['said', 'O'],
#   ['.', 'O']],
#  [['"', 'O'],
#   ['The', 'O'],
#   ['problem', 'O'],
#   ['is', 'O'],
#   ['over', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['president', 'O'],
#   ["'s", 'O'],
#   ['aircraft', 'O'],
#   ['has', 'O'],
# ...
#   ['Cagliari', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Pascal', 'PER'],
#   ['Zuberbuehler', 'PER'],
#   ['(', 'O'],
#   ['Grasshoppers', 'ORG'],
#   [')', 'O'],
#   ['.', 'O']],
#  [['Defenders', 'O'],
#   ['-', 'O'],
#   ['Stephane', 'PER'],
#   ['Henchoz', 'PER'],
#   ['(', 'O'],
#   ['Hamburg', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Marc', 'PER'],
#   ['Hottiger', 'PER'],
#   ['(', 'O'],
#   ['Everton', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Yvan', 'PER'],
#   ['Quentin', 'PER'],
#   ['(', 'O'],
#   ['Sion', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Ramon', 'PER'],
#   ['Vega', 'PER'],
#   ['(', 'O'],
#   ['Cagliari', 'ORG'],
#   [')', 'O'],
#   ['Raphael', 'PER'],
#   ['Wicky', 'PER'],
#   ['(', 'O'],
#   ['Sion', 'ORG'],
#   [')', 'O'],
#   ['.', 'O']],
#  [['Midfielders', 'O'],
#   ['-', 'O'],
#   ['Alexandre', 'PER'],
#   ['Comisetti', 'PER'],
#   ['(', 'O'],
#   ['Grasshoppers', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Antonio', 'PER'],
#   ['Esposito', 'PER'],
#   ['(', 'O'],
#   ['Grasshoppers', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Sebastien', 'PER'],
#   ['Fournier', 'PER'],
#   ['(', 'O'],
#   ['Stuttgart', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Christophe', 'PER'],
#   ['Ohrel', 'PER'],
#   ['(', 'O'],
#   ['Lausanne', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Patrick', 'PER'],
#   ['Sylvestre', 'PER'],
#   ['(', 'O'],
#   ['Sion', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['David', 'PER'],
#   ['Sesa', 'PER'],
#   ['(', 'O'],
#   ['Servette', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Ciriaco', 'PER'],
#   ['Sforza', 'PER'],
#   ['(', 'O'],
#   ['Inter', 'ORG'],
#   ['Milan', 'ORG'],
#   [')', 'O'],
#   ['Murat', 'PER'],
#   ['Yakin', 'PER'],
#   ['(', 'O'],
#   ['Grasshoppers', 'ORG'],
#   [')', 'O'],
#   ['.', 'O']],
#  [['Strikers', 'O'],
#   ['-', 'O'],
#   ['Kubilay', 'PER'],
#   ['Turkyilmaz', 'PER'],
#   ['(', 'O'],
#   ['Grasshoppers', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Adrian', 'PER'],
#   ['Knup', 'PER'],
#   ['(', 'O'],
#   ['Galatasaray', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Christophe', 'PER'],
#   ['Bonvin', 'PER'],
#   ['(', 'O'],
#   ['Sion', 'ORG'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Stephane', 'PER'],
#   ['Chapuisat', 'PER'],
#   ['(', 'O'],
#   ['Borussia', 'ORG'],
#   ['Dortmund', 'ORG'],
#   [')', 'O'],
#   ['.', 'O']],
#  [['ATHLETICS', 'O'],
#   ['-', 'O'],
#   ['IT', 'O'],
#   ["'S", 'O'],
#   ['A', 'O'],
#   ['RECORD', 'O'],
#   ['-', 'O'],
#   ['40,000', 'O'],
#   ['BEERS', 'O'],
#   ['ON', 'O'],
#   ['THE', 'O'],
#   ['HOUSE', 'O'],
#   ['.', 'O']],
#  [['BRUSSELS', 'LOC'], ['1996-08-22', 'O']],
#  [['Spectators', 'O'],
#   ['at', 'O'],
#   ['Friday', 'O'],
#   ["'s", 'O'],
#   ['Brussels', 'LOC'],
#   ['grand', 'O'],
#   ['prix', 'O'],
#   ['meeting', 'O'],
#   ['have', 'O'],
#   ['an', 'O'],
#   ['extra', 'O'],
#   ['incentive', 'O'],
#   ['to', 'O'],
#   ['cheer', 'O'],
#   ['on', 'O'],
#   ['the', 'O'],
#   ['athletes', 'O'],
#   ['to', 'O'],
#   ['world', 'O'],
#   ['record', 'O'],
#   ['performances', 'O'],
#   ['--', 'O'],
#   ['a', 'O'],
#   ['free', 'O'],
#   ['glass', 'O'],
#   ['of', 'O'],
#   ['beer', 'O'],
#   ['.', 'O']],
#  [['A', 'O'],
#   ['Belgian', 'MISC'],
#   ['brewery', 'O'],
#   ['has', 'O'],
#   ['offered', 'O'],
#   ['to', 'O'],
#   ['pay', 'O'],
#   ['for', 'O'],
#   ['a', 'O'],
#   ['free', 'O'],
#   ['round', 'O'],
#   ['of', 'O'],
#   ['drinks', 'O'],
#   ['for', 'O'],
#   ['all', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['40,000', 'O'],
#   ['crowd', 'O'],
#   ['if', 'O'],
#   ['a', 'O'],
#   ['world', 'O'],
#   ['record', 'O'],
#   ['goes', 'O'],
#   ['at', 'O'],
#   ['the', 'O'],
#   ['meeting', 'O'],
#   [',', 'O'],
#   ['organisers', 'O'],
#   ['said', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['.', 'O']],
#  [['It', 'O'],
#   ['could', 'O'],
#   ['be', 'O'],
#   ['one', 'O'],
#   ['of', 'O'],
#   ['the', 'O'],
#   ['most', 'O'],
#   ['expensive', 'O'],
#   ['rounds', 'O'],
#   ['of', 'O'],
#   ['drinks', 'O'],
#   ['ever', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['meeting', 'O'],
#   ['is', 'O'],
#   ['sold', 'O'],
#   ['out', 'O'],
#   ['already', 'O'],
#   ['.', 'O']],
#  [['Two', 'O'],
#   ['world', 'O'],
#   ['records', 'O'],
#   ['are', 'O'],
#   ['in', 'O'],
#   ['serious', 'O'],
#   ['danger', 'O'],
#   ['of', 'O'],
#   ['being', 'O'],
#   ['broken', 'O'],
#   ['at', 'O'],
#   ['the', 'O'],
#   ['meeting', 'O'],
#   ['--', 'O'],
#   ['the', 'O'],
#   ['women', 'O'],
#   ["'s", 'O'],
#   ['1,000', 'O'],
#   ['metres', 'O'],
#   ['and', 'O'],
#   ['the', 'O'],
#   ['men', 'O'],
#   ["'s", 'O'],
#   ['3,000', 'O'],
#   ['metres', 'O'],
#   ['.', 'O']],
#  [['GOLF', 'O'],
#   ['-', 'O'],
#   ['GERMAN', 'MISC'],
#   ['OPEN', 'MISC'],
#   ['FIRST', 'O'],
#   ['ROUND', 'O'],
#   ['SCORES', 'O'],
#   ['.', 'O']],
#  [['STUTTGART', 'LOC'], [',', 'O'], ['Germany', 'LOC'], ['1996-08-22', 'O']],
#  [['Leading', 'O'], ['first', 'O'], ['round', 'O']],
#  [['scores', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['German', 'MISC'],
#   ['Open', 'MISC'],
#   ['golf', 'O'],
#   ['championship', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['(', 'O'],
#   ['Britain', 'LOC']],
#  [['unless', 'O'], ['stated', 'O'], [')', 'O'], [':', 'O']],
#  [['62', 'O'], ['Paul', 'PER'], ['Broadhurst', 'PER']],
#  [['63', 'O'], ['Raymond', 'PER'], ['Russell', 'PER']],
#  [['64', 'O'],
#   ['David', 'PER'],
#   ['J.', 'PER'],
#   ['Russell', 'PER'],
#   [',', 'O'],
#   ['Michael', 'PER'],
#   ['Campbell', 'PER'],
#   ['(', 'O'],
#   ['New', 'LOC'],
#   ['Zealand', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Ian', 'PER']],
#  [['Woosnam', 'PER'],
#   [',', 'O'],
#   ['Bernhard', 'PER'],
#   ['Langer', 'PER'],
#   ['(', 'O'],
#   ['Germany', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Ronan', 'PER'],
#   ['Rafferty', 'PER'],
#   [',', 'O'],
#   ['Mats', 'PER']],
#  [['Lanner', 'PER'],
#   ['(', 'O'],
#   ['Sweden', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Wayne', 'PER'],
#   ['Riley', 'PER'],
#   ['(', 'O'],
#   ['Australia', 'LOC'],
#   [')', 'O']],
#  [['65', 'O'],
#   ['Eamonn', 'PER'],
#   ['Darcy', 'PER'],
#   ['(', 'O'],
#   ['Ireland', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Per', 'PER'],
#   ['Nyman', 'PER'],
#   ['(', 'O'],
#   ['Sweden', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Russell', 'PER'],
#   ['Claydon', 'PER'],
#   [',', 'O']],
#  [['Mark', 'PER'],
#   ['Roe', 'PER'],
#   [',', 'O'],
#   ['Retief', 'PER'],
#   ['Goosen', 'PER'],
#   ['(', 'O'],
#   ['South', 'LOC'],
#   ['Africa', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Carl', 'PER'],
#   ['Suneson', 'PER']],
#  [['66', 'O'],
#   ['Stephen', 'PER'],
#   ['Field', 'PER'],
#   [',', 'O'],
#   ['Paul', 'PER'],
#   ['Lawrie', 'PER'],
#   [',', 'O'],
#   ['Ian', 'PER'],
#   ['Pyman', 'PER'],
#   [',', 'O'],
#   ['Max', 'PER'],
#   ['Anglert', 'PER']],
#  [['(', 'O'],
#   ['Sweden', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Miles', 'PER'],
#   ['Tunnicliff', 'PER'],
#   [',', 'O'],
#   ['Christian', 'PER'],
#   ['Cevaer', 'PER'],
#   ['(', 'O'],
#   ['France', 'LOC'],
#   [')', 'O'],
#   [',', 'O']],
#  [['Des', 'PER'],
#   ['Smyth', 'PER'],
#   ['(', 'O'],
#   ['Ireland', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['David', 'PER'],
#   ['Carter', 'PER'],
#   [',', 'O'],
#   ['Lee', 'PER'],
#   ['Westwood', 'PER'],
#   [',', 'O'],
#   ['Greg', 'PER']],
#  [['Chalmers', 'PER'],
#   ['(', 'O'],
#   ['Australia', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Miguel', 'PER'],
#   ['Angel', 'PER'],
#   ['Martin', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O']],
#  [['Thomas', 'PER'],
#   ['Bjorn', 'PER'],
#   ['(', 'O'],
#   ['Denmark', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Fernando', 'PER'],
#   ['Roca', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Derrick', 'PER']],
#  [['Cooper', 'PER']],
#  [['67', 'O'],
#   ['Jeff', 'PER'],
#   ['Hawksworth', 'PER'],
#   [',', 'O'],
#   ['Padraig', 'PER'],
#   ['Harrington', 'PER'],
#   ['(', 'O'],
#   ['Ireland', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Michael', 'PER']],
#  [['Welch', 'PER'],
#   [',', 'O'],
#   ['Thomas', 'PER'],
#   ['Gogele', 'PER'],
#   ['(', 'O'],
#   ['Germany', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Paul', 'PER'],
#   ['McGinley', 'PER'],
#   ['(', 'O'],
#   ['Ireland', 'LOC'],
#   [')', 'O'],
#   [',', 'O']],
#  [['Gary', 'PER'],
#   ['Orr', 'PER'],
#   [',', 'O'],
#   ['Jose-Maria', 'PER'],
#   ['Canizares', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Michael', 'PER'],
#   ['Jonzon', 'PER']],
#  [['(', 'O'],
#   ['Sweden', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Paul', 'PER'],
#   ['Eales', 'PER'],
#   [',', 'O'],
#   ['David', 'PER'],
#   ['Williams', 'PER'],
#   [',', 'O'],
#   ['Andrew', 'PER'],
#   ['Coltart', 'PER'],
#   [',', 'O']],
#  [['Jonathan', 'PER'],
#   ['Lomas', 'PER'],
#   [',', 'O'],
#   ['Jose', 'PER'],
#   ['Rivero', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Robert', 'PER'],
#   ['Karlsson', 'PER']],
#  [['(', 'O'],
#   ['Sweden', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Marcus', 'PER'],
#   ['Wills', 'PER'],
#   [',', 'O'],
#   ['Pedro', 'PER'],
#   ['Linhart', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Jamie', 'PER']],
#  [['Spence', 'PER'],
#   [',', 'O'],
#   ['Terry', 'PER'],
#   ['Price', 'PER'],
#   ['(', 'O'],
#   ['Australia', 'LOC'],
#   [')', 'O'],
#   [',', 'O'],
#   ['Juan', 'PER'],
#   ['Carlos', 'PER'],
#   ['Pinero', 'PER'],
#   ['(', 'O'],
#   ['Spain', 'LOC'],
#   [')', 'O'],
#   [',', 'O']],
#  [['Mark', 'PER'], ['Mouland', 'PER']],
#  [['SOCCER', 'O'],
#   ['-', 'O'],
#   ['UEFA', 'ORG'],
#   ['REWARDS', 'O'],
#   ['THREE', 'O'],
#   ['COUNTRIES', 'O'],
#   ['FOR', 'O'],
#   ['FAIR', 'O'],
#   ['PLAY', 'O'],
#   ['.', 'O']],
#  [['GENEVA', 'LOC'], ['1996-08-22', 'O']],
#  [['Norway', 'LOC'],
#   [',', 'O'],
#   ['England', 'LOC'],
#   ['and', 'O'],
#   ['Sweden', 'LOC'],
#   ['were', 'O'],
#   ['rewarded', 'O'],
#   ['for', 'O'],
#   ['their', 'O'],
#   ['fair', 'O'],
#   ['play', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['with', 'O'],
#   ['an', 'O'],
#   ['additional', 'O'],
#   ['place', 'O'],
#   ['in', 'O'],
#   ['the', 'O'],
#   ['1997-98', 'O'],
#   ['UEFA', 'MISC'],
#   ['Cup', 'MISC'],
#   ['competition', 'O'],
#   ['.', 'O']],
#  [['Norway', 'LOC'],
#   ['headed', 'O'],
#   ['the', 'O'],
#   ['UEFA', 'MISC'],
#   ['Fair', 'MISC'],
#   ['Play', 'MISC'],
#   ['rankings', 'O'],
#   ['for', 'O'],
#   ['1995-96', 'O'],
#   ['with', 'O'],
#   ['8.62', 'O'],
#   ['points', 'O'],
#   [',', 'O'],
#   ['ahead', 'O'],
#   ['of', 'O'],
#   ['England', 'LOC'],
#   ['with', 'O'],
#   ['8.61', 'O'],
#   ['and', 'O'],
#   ['Sweden', 'LOC'],
#   ['8.57', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['rankings', 'O'],
#   ['are', 'O'],
#   ['based', 'O'],
#   ['on', 'O'],
#   ['a', 'O'],
#   ['formula', 'O'],
#   ['that', 'O'],
#   ['takes', 'O'],
#   ['into', 'O'],
#   ['account', 'O'],
#   ['many', 'O'],
#   ['factors', 'O'],
#   ['including', 'O'],
#   ['red', 'O'],
#   ['and', 'O'],
#   ['yellow', 'O'],
#   ['cards', 'O'],
#   [',', 'O'],
#   ['and', 'O'],
#   ['coaching', 'O'],
#   ['and', 'O'],
#   ['spectators', 'O'],
#   ["'", 'O'],
#   ['behaviour', 'O'],
#   ['at', 'O'],
#   ['matches', 'O'],
#   ['played', 'O'],
#   ['at', 'O'],
#   ['an', 'O'],
#   ['international', 'O'],
#   ['level', 'O'],
#   ['by', 'O'],
#   ['clubs', 'O'],
#   ['and', 'O'],
#   ['national', 'O'],
#   ['teams', 'O'],
#   ['.', 'O']],
#  [['Only', 'O'],
#   ['the', 'O'],
#   ['top', 'O'],
#   ['three', 'O'],
#   ['countries', 'O'],
#   ['are', 'O'],
#   ['allocated', 'O'],
#   ['additional', 'O'],
#   ['places', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['UEFA', 'MISC'],
#   ['Fair', 'MISC'],
#   ['Play', 'MISC'],
#   ['rankings', 'O'],
#   ['are', 'O'],
#   [':', 'O'],
#   ['1', 'O'],
#   ['.', 'O']],
#  [['Norway', 'LOC'], ['8.62', 'O'], ['points', 'O']],
#  [['2.', 'O'], ['England', 'LOC'], ['8.61', 'O']],
#  [['3.', 'O'], ['Sweden', 'LOC'], ['8.57', 'O']],
#  [['4.', 'O'], ['Faroe', 'LOC'], ['Islands', 'LOC'], ['8.56', 'O']],
#  [['5.', 'O'], ['Wales', 'LOC'], ['8.54', 'O']],
#  [['6.', 'O'], ['Estonia', 'LOC'], ['8.52', 'O']],
#  [['7.', 'O'], ['Ireland', 'LOC'], ['8.45', 'O']],
#  [['8.', 'O'], ['Belarus', 'LOC'], ['8.39', 'O']],
#  [['9.', 'O'], ['Iceland', 'LOC'], ['8.35', 'O']],
#  [['10.', 'O'], ['Netherlands', 'LOC'], ['8.30', 'O']],
#  [['10.', 'O'], ['Denmark', 'LOC'], ['8.30', 'O']],
#  [['10.', 'O'], ['Germany', 'LOC'], ['8.30', 'O']],
#  [['13.', 'O'], ['Scotland', 'LOC'], ['8.29', 'O']],
#  [['13.', 'O'], ['Latvia', 'LOC'], ['8.29', 'O']],
#  [['15.', 'O'], ['Moldova', 'LOC'], ['8.24', 'O']],
#  [['16.', 'O'], ['Yugoslavia', 'LOC'], ['8.22', 'O']],
#  [['16.', 'O'], ['Belgium', 'LOC'], ['8.22', 'O']],
#  [['18.', 'O'], ['Luxembourg', 'LOC'], ['8.20', 'O']],
#  [['19.', 'O'], ['France', 'LOC'], ['8.18', 'O']],
#  [['20.', 'O'], ['Israel', 'LOC'], ['8.17', 'O']],
#  [['21.', 'O'], ['Switzerland', 'LOC'], ['8.15', 'O']],
#  [['21.', 'O'], ['Slovakia', 'LOC'], ['8.15', 'O']],
#  [['23.', 'O'], ['Poland', 'LOC'], ['8.12', 'O']],
#  [['23.', 'O'], ['Portugal', 'LOC'], ['8.12', 'O']],
#  [['25.', 'O'], ['Georgia', 'LOC'], ['8.10', 'O']],
#  [['26.', 'O'], ['Ukraine', 'LOC'], ['8.09', 'O']],
#  [['26.', 'O'], ['Spain', 'LOC'], ['8.09', 'O']],
#  [['26.', 'O'], ['Finland', 'LOC'], ['8.09', 'O']],
#  [['29.', 'O'], ['Macedonia', 'LOC'], ['8.07', 'O']],
#  [['30.', 'O'], ['Lithuania', 'LOC'], ['8.06', 'O']],
#  [['31.', 'O'], ['Austria', 'LOC'], ['8.05', 'O']],
#  [['32.', 'O'], ['Russia', 'LOC'], ['8.03', 'O']],
#  [['33.', 'O'], ['Romania', 'LOC'], ['8.02', 'O']],
#  [['33.', 'O'], ['Turkey', 'LOC'], ['8.02', 'O']],
#  [['35.', 'O'], ['Hungary', 'LOC'], ['7.98', 'O']],
#  [['36.', 'O'], ['Czech', 'LOC'], ['Republic', 'LOC'], ['7.95', 'O']],
#  [['37.', 'O'], ['Greece', 'LOC'], ['7.89', 'O']],
#  [['37.', 'O'], ['Northern', 'LOC'], ['Ireland', 'LOC'], ['7.89', 'O']],
#  [['39.', 'O'], ['Italy', 'LOC'], ['7.85', 'O']],
#  [['40.', 'O'], ['Cyprus', 'LOC'], ['7.83', 'O']],
#  [['41.', 'O'], ['Armenia', 'LOC'], ['7.80', 'O']],
#  [['42.', 'O'], ['Slovenia', 'LOC'], ['7.77', 'O']],
#  [['43.', 'O'], ['Croatia', 'LOC'], ['7.75', 'O']],
#  [['44.', 'O'], ['Bulgaria', 'LOC'], ['7.73', 'O']],
#  [['45.', 'O'], ['Malta', 'LOC'], ['7.40', 'O']],
#  [['CRICKET', 'O'],
#   ['-', 'O'],
#   ['POLICE', 'O'],
#   ['COMMANDOS', 'O'],
#   ['ON', 'O'],
#   ['HAND', 'O'],
#   ['FOR', 'O'],
#   ['AUSTRALIANS', 'MISC'],
#   ["'", 'O'],
#   ['FIRST', 'O'],
#   ['MATCH', 'O'],
#   ['.', 'O']],
#  [['COLOMBO', 'LOC'], ['1996-08-22', 'O']],
#  [['Armed', 'O'],
#   ['police', 'O'],
#   ['commandos', 'O'],
#   ['patrolled', 'O'],
#   ['the', 'O'],
#   ['ground', 'O'],
#   ['when', 'O'],
#   ['Australia', 'LOC'],
#   ['opened', 'O'],
#   ['their', 'O'],
#   ['short', 'O'],
#   ['tour', 'O'],
#   ['of', 'O'],
#   ['Sri', 'LOC'],
#   ['Lanka', 'LOC'],
#   ['with', 'O'],
#   ['a', 'O'],
#   ['five-run', 'O'],
#   ['win', 'O'],
#   ['over', 'O'],
#   ['the', 'O'],
#   ['country', 'O'],
#   ["'s", 'O'],
#   ['youth', 'O'],
#   ['team', 'O'],
#   ['on', 'O'],
#   ['Thursday', 'O'],
#   ['.', 'O']],
#  [['Australia', 'LOC'],
#   [',', 'O'],
#   ['in', 'O'],
#   ['Sri', 'LOC'],
#   ['Lanka', 'LOC'],
#   ['for', 'O'],
#   ['a', 'O'],
#   ['limited', 'O'],
#   ['overs', 'O'],
#   ['tournament', 'O'],
#   ['which', 'O'],
#   ['also', 'O'],
#   ['includes', 'O'],
#   ['India', 'LOC'],
#   ['and', 'O'],
#   ['Zimbabwe', 'LOC'],
#   [',', 'O'],
#   ['have', 'O'],
#   ['been', 'O'],
#   ['promised', 'O'],
#   ['the', 'O'],
#   ['presence', 'O'],
#   ['of', 'O'],
#   ['commandos', 'O'],
#   [',', 'O'],
#   ['sniffer', 'O'],
#   ['dogs', 'O'],
#   ['and', 'O'],
#   ['plainclothes', 'O'],
#   ['policemen', 'O'],
#   ['to', 'O'],
#   ['ensure', 'O'],
#   ['the', 'O'],
#   ['tournament', 'O'],
#   ['is', 'O'],
#   ['trouble-free', 'O'],
#   ['.', 'O']],
#  [['They', 'O'],
#   ['are', 'O'],
#   ['making', 'O'],
#   ['their', 'O'],
#   ['first', 'O'],
#   ['visit', 'O'],
#   ['to', 'O'],
#   ['the', 'O'],
#   ['island', 'O'],
#   ['since', 'O'],
#   ['boycotting', 'O'],
#   ['a', 'O'],
#   ['World', 'MISC'],
#   ['Cup', 'MISC'],
#   ['fixture', 'O'],
#   ['in', 'O'],
#   ['February', 'O'],
#   ['because', 'O'],
#   ['of', 'O'],
#   ['fears', 'O'],
#   ['over', 'O'],
#   ['ethnic', 'O'],
#   ['violence', 'O'],
#   ['.', 'O']],
#  [['Australia', 'LOC'],
#   [',', 'O'],
#   ['batting', 'O'],
#   ['first', 'O'],
#   ['in', 'O'],
#   ['Thursday', 'O'],
#   ["'s", 'O'],
#   ['the', 'O'],
#   ['warm-up', 'O'],
#   ['match', 'O'],
#   [',', 'O'],
#   ['scored', 'O'],
#   ['251', 'O'],
#   ['for', 'O'],
#   ['seven', 'O'],
#   ['from', 'O'],
#   ['their', 'O'],
#   ['50', 'O'],
#   ['overs', 'O'],
#   ['.', 'O']],
#  [['Ricky', 'PER'],
#   ['Ponting', 'PER'],
#   ['led', 'O'],
#   ['the', 'O'],
#   ['way', 'O'],
#   ['with', 'O'],
#   ['100', 'O'],
#   ['off', 'O'],
#   ['119', 'O'],
#   ['balls', 'O'],
#   ['with', 'O'],
#   ['two', 'O'],
#   ['sixes', 'O'],
#   ['and', 'O'],
#   ['nine', 'O'],
#   ['fours', 'O'],
#   ['before', 'O'],
#   ['retiring', 'O'],
#   ['.', 'O']],
#  [['The', 'O'],
#   ['youth', 'O'],
#   ['side', 'O'],
#   ['replied', 'O'],
#   ['with', 'O'],
#   ['246', 'O'],
#   ['for', 'O'],
#   ['seven', 'O'],
#   ['.', 'O']],
#  ...]

# %%
len(docs), type(docs)
# Out:
# (14042, list)

# %%
docs[0]
# Out:
# [['EU', 'ORG'],
#  ['rejects', 'O'],
#  ['German', 'MISC'],
#  ['call', 'O'],
#  ['to', 'O'],
#  ['boycott', 'O'],
#  ['British', 'MISC'],
#  ['lamb', 'O'],
#  ['.', 'O']]

# %%
X_train, y_train = du.docs_to_windows(docs, word_to_num, tag_to_num)

# %%
X_train.shape
# Out:
# (203621, 3)

# %%
y_train.shape
# Out:
# (203621,)

# %%
X_train
# Out:
# array([[   30,  6659, 12637],
#        [ 6659, 12637,   445],
#        [12637,   445,   977],
#        ...,
#        [10797,     0,  2366],
#        [    0,  2366,     0],
#        [ 2366,     0,    31]])

# %%
y_train
# Out:
# array([3, 0, 2, ..., 0, 3, 0])

# %%
sess = tf.InteractiveSession()

# %% [markdown]
# ## placeholders

# %%
input_placeholder   = tf.placeholder(tf.int32, [None, config.window_size], name="input_placeholder")
labels_placeholder  = tf.placeholder(tf.int32, [None, config.label_size], name="labels_placeholder")
dropout_placeholder = tf.placeholder(tf.float32, [], name="dropout_placeholder")

# %% [markdown]
# ## Embedding

# %%
L = tf.Variable(tf.random_uniform([len(wv), config.embed_size], -1.0, 1.0), name="L")

# %%
L

# %%
L.get_shape()
# Out:
# TensorShape([Dimension(100232), Dimension(50)])

# %%
tf.nn.embedding_lookup(L, input_placeholder)
# Out:
# <tf.Tensor 'embedding_lookup:0' shape=(?, 3, 50) dtype=float32>

# %%
window = tf.reshape(tf.nn.embedding_lookup(L, input_placeholder), [-1, config.window_size * config.embed_size])

# %%
window
# Out:
# <tf.Tensor 'Reshape:0' shape=(?, 150) dtype=float32>

# %% [markdown]
# ## Model

# %%
xavier_initializer = xavier_weight_init()

# %%
with tf.variable_scope("Layerrr"):
    W = tf.get_variable("W", initializer=xavier_initializer([config.window_size*config.embed_size, config.hidden_size]))
    b1 = tf.get_variable("b1", [config.hidden_size])
    tf.matmul(window, W) + b1
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-36-6afe35404948> in <module>()
#       1 with tf.variable_scope("Layerrr"):
# ----> 2     W = tf.get_variable("W", initializer=xavier_initializer([config.window_size*config.embed_size, config.hidden_size]))
#       3     b1 = tf.get_variable("b1", [config.hidden_size])
#       4     tf.matmul(window, W)
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, custom_getter)
#    1022       collections=collections, caching_device=caching_device,
#    1023       partitioner=partitioner, validate_shape=validate_shape,
# -> 1024       custom_getter=custom_getter)
#    1025
#    1026
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, custom_getter)
#     848           collections=collections, caching_device=caching_device,
#     849           partitioner=partitioner, validate_shape=validate_shape,
# --> 850           custom_getter=custom_getter)
#     851
#     852   def _get_partitioned_variable(self,
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, custom_getter)
#     344           reuse=reuse, trainable=trainable, collections=collections,
#     345           caching_device=caching_device, partitioner=partitioner,
# --> 346           validate_shape=validate_shape)
#     347
#     348   def _get_partitioned_variable(
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape)
#     329           initializer=initializer, regularizer=regularizer, reuse=reuse,
#     330           trainable=trainable, collections=collections,
# --> 331           caching_device=caching_device, validate_shape=validate_shape)
#     332
#     333     if custom_getter is not None:
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape)
#     630                          " Did you mean to set reuse=True in VarScope? "
#     631                          "Originally defined at:\n\n%s" % (
# --> 632                              name, "".join(traceback.format_list(tb))))
#     633       found_var = self._vars[name]
#     634       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable Layerrr/W already exists, disallowed. Did you mean to set reuse=True in VarScope? Originally defined at:
#
#   File "<ipython-input-35-6afe35404948>", line 2, in <module>
#     W = tf.get_variable("W", initializer=xavier_initializer([config.window_size*config.embed_size, config.hidden_size]))
#   File "/Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):

# %%
h = tf.tanh(tf.matmul(window, W) + b1)

# %%
h
# Out:
# <tf.Tensor 'Tanh:0' shape=(?, 100) dtype=float32>

# %%
W.get_shape()
# Out:
# TensorShape([Dimension(150), Dimension(100)])

# %%
b1.get_shape()
# Out:
# TensorShape([Dimension(100)])

# %%
with tf.variable_scope("Softmax"):
    U = tf.get_variable("U", initializer=xavier_initializer([config.hidden_size, config.label_size]))
    b2 = tf.get_variable("b2", [config.label_size])

# %%
output = tf.matmul(h, U) + b2

# %%
output
# Out:
# <tf.Tensor 'add_2:0' shape=(?, 5) dtype=float32>

# %% [markdown]
# ## Loss

# %%
y = output

# %%
losses = tf.nn.softmax_cross_entropy_with_logits(labels=labels_placeholder, logits=y)

# %%
losses
# Out:
# <tf.Tensor 'Reshape_3:0' shape=(?,) dtype=float32>

# %% [markdown]
# # Test drive

# %%
sess.run(tf.global_variables_initializer())

# %%
sess.run(output, feed_dict={input_placeholder: X_train, labels_placeholder: y_train})
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-46-0678962d732b> in <module>()
# ----> 1 sess.run(output, feed_dict={input_placeholder: X_train, labels_placeholder: y_train})
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/gibbon/miniconda3/envs/stanford/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     941                 'Cannot feed value of shape %r for Tensor %r, '
#     942                 'which has shape %r'
# --> 943                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     944           if not self.graph.is_feedable(subfeed_t):
#     945             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (203621,) for Tensor u'labels_placeholder:0', which has shape '(?, 5)'
